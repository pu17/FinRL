# %% [markdown]
# # Stock NeurIPS2018 Part 2. Train
# This series is a reproduction of *the process in the paper Practical Deep Reinforcement Learning Approach for Stock Trading*.
#
# This is the second part of the NeurIPS2018 series, introducing how to use FinRL to make data into the gym form environment, and train DRL agents on it.
#
# Other demos can be found at the repo of [FinRL-Tutorials]((https://github.com/AI4Finance-Foundation/FinRL-Tutorials)).

# %% [markdown]
# # Part 1. Install Packages

# %%
## install finrl library
#!pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
from stable_baselines3.common.logger import configure

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# # Part 2. Build A Market Environment in OpenAI Gym-style

# %% [markdown]
# ![rl_diagram_transparent_bg.png](data:image/png;base64,...)

# %% [markdown]
# The core element in reinforcement learning are **agent** and **environment**. You can understand RL as the following process:
#
# The agent is active in a world, which is the environment. It observe its current condition as a **state**, and is allowed to do certain **actions**. After the agent execute an action, it will arrive at a new state. At the same time, the environment will have feedback to the agent called **reward**, a numerical signal that tells how good or bad the new state is. As the figure above, agent and environment will keep doing this interaction.
#
# The goal of agent is to get as much cumulative reward as possible. Reinforcement learning is the method that agent learns to improve its behavior and achieve that goal.

# %% [markdown]
# To achieve this in Python, we follow the OpenAI gym style to build the stock data into environment.
#
# state-action-reward are specified as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes the price data and technical indicators based on the past data. It will learn by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 constituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.

# %% [markdown]
# ## Read data
#
# We first read the .csv file of our training data into dataframe.

# %%
train = pd.read_csv('train_data.csv')

# If you are not using the data generated from part 1 of this tutorial, make sure 
# it has the columns and index in the form that could be make into the environment. 
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']

# %% [markdown]
# ## Construct the environment

# %% [markdown]
# Calculate and specify the parameters we need for constructing the environment.

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + (len(INDICATORS))*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
print(len(INDICATORS))
# Out:
# 8

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 3: Train DRL Agents
# * Here, the DRL algorithms are from **[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)**. It's a library that implemented popular DRL algorithms using pytorch, succeeding to its old version: Stable Baselines.
# * Users are also encouraged to try **[ElegantRL](https://github.com/AI4Finance-Foundation/ElegantRL)** and **[Ray RLlib](https://github.com/ray-project/ray)**.

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ## Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# --------------------------------------
# | time/                 |            |
# |    fps                | 1159       |
# |    iterations         | 100        |
# |    time_elapsed       | 0          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 7.71       |
# |    reward             | -7.0215254 |
# |    std                | 1.01       |
# |    value_loss         | 26.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1488      |
# |    iterations         | 200       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 3.89      |
# |    reward             | -1.077901 |
# |    std                | 1.02      |
# |    value_loss         | 5.04      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1476        |
# |    iterations         | 300         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -1.46       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | 0.415       |
# |    reward             | 0.075666584 |
# |    std                | 1.04        |
# |    value_loss         | 0.0739      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1572       |
# |    iterations         | 400        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -1.46      |
# |    explained_variance | 0.0106     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -14.5      |
# |    reward             | -4.1411233 |
# |    std                | 1.04       |
# |    value_loss         | 163        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1508       |
# |    iterations         | 500        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -1.46      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 0.97       |
# |    reward             | -2.6596797 |
# |    std                | 1.04       |
# |    value_loss         | 3.06       |
# --------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1558           |
# |    iterations         | 600            |
# |    time_elapsed       | 1              |
# |    total_timesteps    | 3000           |
# | train/                |                |
# |    entropy_loss       | -1.47          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 599            |
# |    policy_loss        | 0.634          |
# |    reward             | -6.5827124e-05 |
# |    std                | 1.06           |
# |    value_loss         | 0.494          |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1623      |
# |    iterations         | 700       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.48     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -3.29     |
# |    reward             | 0.5487836 |
# |    std                | 1.06      |
# |    value_loss         | 4.05      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1667       |
# |    iterations         | 800        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -1.47      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -1.66      |
# |    reward             | -0.9412551 |
# |    std                | 1.05       |
# |    value_loss         | 5.85       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1707      |
# |    iterations         | 900       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -1.47     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -1.64     |
# |    reward             | 1.1802522 |
# |    std                | 1.05      |
# |    value_loss         | 11        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1744       |
# |    iterations         | 1000       |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -1.49      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 8.48       |
# |    reward             | -1.5221606 |
# |    std                | 1.07       |
# |    value_loss         | 58.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1771       |
# |    iterations         | 1100       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -1.49      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -15        |
# |    reward             | -2.3280022 |
# |    std                | 1.08       |
# |    value_loss         | 200        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1764       |
# |    iterations         | 1200       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -1.49      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 5.59       |
# |    reward             | 0.20536564 |
# |    std                | 1.08       |
# |    value_loss         | 11.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1785       |
# |    iterations         | 1300       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -1.49      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 1.12       |
# |    reward             | 0.54580563 |
# |    std                | 1.08       |
# |    value_loss         | 3.03       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1783      |
# |    iterations         | 1400      |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -0.0349   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -3.78     |
# |    reward             | 3.5462883 |
# |    std                | 1.08      |
# |    value_loss         | 16.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1773     |
# |    iterations         | 1500     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 1.09     |
# |    reward             | 2.036501 |
# |    std                | 1.09     |
# |    value_loss         | 7.74     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1730       |
# |    iterations         | 1600       |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -1.5       |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -4.54      |
# |    reward             | -3.3333771 |
# |    std                | 1.09       |
# |    value_loss         | 16.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1716       |
# |    iterations         | 1700       |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -1.51      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -0.257     |
# |    reward             | 0.09486651 |
# |    std                | 1.09       |
# |    value_loss         | 0.0351     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1677       |
# |    iterations         | 1800       |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -1.51      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 10         |
# |    reward             | 0.71852744 |
# |    std                | 1.1        |
# |    value_loss         | 25         |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1663         |
# |    iterations         | 1900         |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -1.52        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | -4.53        |
# |    reward             | -0.061508097 |
# |    std                | 1.11         |
# |    value_loss         | 12.6         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1659        |
# |    iterations         | 2000        |
# |    time_elapsed       | 6           |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -1.53       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.58        |
# |    reward             | -0.12353018 |
# |    std                | 1.12        |
# |    value_loss         | 0.169       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1661       |
# |    iterations         | 2100       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -1.53      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | -2.44      |
# |    reward             | 0.52535653 |
# |    std                | 1.12       |
# |    value_loss         | 3.83       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1644       |
# |    iterations         | 2200       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -1.52      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | 18.4       |
# |    reward             | -4.1685557 |
# |    std                | 1.11       |
# |    value_loss         | 176        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1616     |
# |    iterations         | 2300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 2.61     |
# |    reward             | 4.348001 |
# |    std                | 1.1      |
# |    value_loss         | 6.5      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1619      |
# |    iterations         | 2400      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.52     |
# |    explained_variance | -0.0645   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.827    |
# |    reward             | 2.4135206 |
# |    std                | 1.11      |
# |    value_loss         | 1.16      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1586     |
# |    iterations         | 2500     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 0.0733   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 2.01     |
# |    reward             | 8.061078 |
# |    std                | 1.11     |
# |    value_loss         | 9.04     |
# ------------------------------------
# day: 1403, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1805462.63
# total_reward: 805462.63
# total_cost: 1822.84
# total_trades: 1399
# Sharpe: 0.460
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 1590       |
# |    iterations         | 2600       |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -1.54      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | -8.97      |
# |    reward             | -1.4998151 |
# |    std                | 1.12       |
# |    value_loss         | 34.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1599      |
# |    iterations         | 2700      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -1.53     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | 0.745     |
# |    reward             | 2.9328277 |
# |    std                | 1.12      |
# |    value_loss         | 1.11      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1607      |
# |    iterations         | 2800      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.52     |
# |    explained_variance | 0.00272   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -10.4     |
# |    reward             | 4.4419947 |
# |    std                | 1.11      |
# |    value_loss         | 140       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1611      |
# |    iterations         | 2900      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.54     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 4.41      |
# |    reward             | -2.078086 |
# |    std                | 1.13      |
# |    value_loss         | 18.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1623       |
# |    iterations         | 3000       |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -1.54      |
# |    explained_variance | -0.0124    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | -4.14      |
# |    reward             | -0.9113178 |
# |    std                | 1.12       |
# |    value_loss         | 13.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1635        |
# |    iterations         | 3100        |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -1.53       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | -0.316      |
# |    reward             | -0.16447626 |
# |    std                | 1.12        |
# |    value_loss         | 0.0817      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1647       |
# |    iterations         | 3200       |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -1.52      |
# |    explained_variance | 0.00397    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -6.29      |
# |    reward             | -2.5710697 |
# |    std                | 1.11       |
# |    value_loss         | 19.1       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1657        |
# |    iterations         | 3300        |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 16500       |
# | train/                |             |
# |    entropy_loss       | -1.53       |
# |    explained_variance | 2.38e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3299        |
# |    policy_loss        | -2.72       |
# |    reward             | -0.49801248 |
# |    std                | 1.11        |
# |    value_loss         | 4.05        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1661        |
# |    iterations         | 3400        |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 17000       |
# | train/                |             |
# |    entropy_loss       | -1.51       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3399        |
# |    policy_loss        | -0.599      |
# |    reward             | 0.014026263 |
# |    std                | 1.1         |
# |    value_loss         | 0.321       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1668       |
# |    iterations         | 3500       |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -1.51      |
# |    explained_variance | -0.0409    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | -3.33      |
# |    reward             | -1.0196303 |
# |    std                | 1.09       |
# |    value_loss         | 2.39       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1669     |
# |    iterations         | 3600     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.529   |
# |    reward             | 8.103724 |
# |    std                | 1.07     |
# |    value_loss         | 0.629    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1678      |
# |    iterations         | 3700      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 0.317     |
# |    reward             | 0.2191211 |
# |    std                | 1.08      |
# |    value_loss         | 0.107     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1676        |
# |    iterations         | 3800        |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 19000       |
# | train/                |             |
# |    entropy_loss       | -1.49       |
# |    explained_variance | -0.00303    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3799        |
# |    policy_loss        | -8.59       |
# |    reward             | -0.48227972 |
# |    std                | 1.07        |
# |    value_loss         | 56.7        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1684      |
# |    iterations         | 3900      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -21.9     |
# |    reward             | 3.012055  |
# |    std                | 1.08      |
# |    value_loss         | 119       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1683       |
# |    iterations         | 4000       |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -1.5       |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | 4.82       |
# |    reward             | -2.2543974 |
# |    std                | 1.08       |
# |    value_loss         | 10.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1684      |
# |    iterations         | 4100      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -1.51     |
# |    explained_variance | 0.00131   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 11        |
# |    reward             | 1.6633316 |
# |    std                | 1.09      |
# |    value_loss         | 75.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1684      |
# |    iterations         | 4200      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -1.51     |
# |    explained_variance | 0.00514   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -5.76     |
# |    reward             | -3.498059 |
# |    std                | 1.09      |
# |    value_loss         | 42.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1684       |
# |    iterations         | 4300       |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 21500      |
# | train/                |            |
# |    entropy_loss       | -1.5       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4299       |
# |    policy_loss        | -2.68      |
# |    reward             | 0.03988482 |
# |    std                | 1.09       |
# |    value_loss         | 3.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1691       |
# |    iterations         | 4400       |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -1.51      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | -1.18      |
# |    reward             | -1.8395773 |
# |    std                | 1.1        |
# |    value_loss         | 2.77       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1680         |
# |    iterations         | 4500         |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 22500        |
# | train/                |              |
# |    entropy_loss       | -1.53        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4499         |
# |    policy_loss        | 0.352        |
# |    reward             | -0.048545633 |
# |    std                | 1.11         |
# |    value_loss         | 0.0649       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1657        |
# |    iterations         | 4600        |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 23000       |
# | train/                |             |
# |    entropy_loss       | -1.52       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4599        |
# |    policy_loss        | -0.956      |
# |    reward             | -0.44645786 |
# |    std                | 1.11        |
# |    value_loss         | 6.31        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1661      |
# |    iterations         | 4700      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -1.53     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 5.67      |
# |    reward             | 0.7415313 |
# |    std                | 1.12      |
# |    value_loss         | 18.7      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1668         |
# |    iterations         | 4800         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 24000        |
# | train/                |              |
# |    entropy_loss       | -1.53        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4799         |
# |    policy_loss        | 0.024        |
# |    reward             | -0.109953694 |
# |    std                | 1.12         |
# |    value_loss         | 0.00677      |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1669      |
# |    iterations         | 4900      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.53     |
# |    explained_variance | -0.114    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -1.8      |
# |    reward             | 0.4738105 |
# |    std                | 1.12      |
# |    value_loss         | 1.87      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1671     |
# |    iterations         | 5000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -2.77    |
# |    reward             | 1.015069 |
# |    std                | 1.1      |
# |    value_loss         | 6.33     |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1668         |
# |    iterations         | 5100         |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 25500        |
# | train/                |              |
# |    entropy_loss       | -1.52        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5099         |
# |    policy_loss        | -1.02        |
# |    reward             | -0.021363748 |
# |    std                | 1.11         |
# |    value_loss         | 0.167        |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1664         |
# |    iterations         | 5200         |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 26000        |
# | train/                |              |
# |    entropy_loss       | -1.54        |
# |    explained_variance | 0.121        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5199         |
# |    policy_loss        | 0.415        |
# |    reward             | -0.061760724 |
# |    std                | 1.13         |
# |    value_loss         | 0.942        |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1664      |
# |    iterations         | 5300      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.54     |
# |    explained_variance | 0.0131    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 8.8       |
# |    reward             | 12.108455 |
# |    std                | 1.13      |
# |    value_loss         | 62        |
# -------------------------------------
# day: 1403, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1811078.37
# total_reward: 811078.37
# total_cost: 1734.99
# total_trades: 1398
# Sharpe: 0.461
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 1666       |
# |    iterations         | 5400       |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -1.56      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | 5.05       |
# |    reward             | -0.7327282 |
# |    std                | 1.15       |
# |    value_loss         | 9.93       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1666         |
# |    iterations         | 5500         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 27500        |
# | train/                |              |
# |    entropy_loss       | -1.58        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5499         |
# |    policy_loss        | -17.1        |
# |    reward             | -0.063098334 |
# |    std                | 1.17         |
# |    value_loss         | 94.4         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1660      |
# |    iterations         | 5600      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.57     |
# |    explained_variance | -0.00439  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 37.6      |
# |    reward             | 14.919827 |
# |    std                | 1.16      |
# |    value_loss         | 459       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1659       |
# |    iterations         | 5700       |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -1.58      |
# |    explained_variance | 2.38e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | 5          |
# |    reward             | -1.6657948 |
# |    std                | 1.17       |
# |    value_loss         | 12.8       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1646        |
# |    iterations         | 5800        |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 29000       |
# | train/                |             |
# |    entropy_loss       | -1.57       |
# |    explained_variance | 0.0136      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5799        |
# |    policy_loss        | -1.95       |
# |    reward             | -0.12469537 |
# |    std                | 1.17        |
# |    value_loss         | 1.49        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1650         |
# |    iterations         | 5900         |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 29500        |
# | train/                |              |
# |    entropy_loss       | -1.58        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5899         |
# |    policy_loss        | 0.0522       |
# |    reward             | -0.021817993 |
# |    std                | 1.17         |
# |    value_loss         | 0.00151      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1646       |
# |    iterations         | 6000       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -1.57      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | -13.6      |
# |    reward             | -3.8267457 |
# |    std                | 1.16       |
# |    value_loss         | 55.8       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1654        |
# |    iterations         | 6100        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 30500       |
# | train/                |             |
# |    entropy_loss       | -1.57       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6099        |
# |    policy_loss        | 2.24        |
# |    reward             | -0.12518595 |
# |    std                | 1.17        |
# |    value_loss         | 6.62        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1650        |
# |    iterations         | 6200        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 31000       |
# | train/                |             |
# |    entropy_loss       | -1.57       |
# |    explained_variance | -2.38e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6199        |
# |    policy_loss        | -1.39       |
# |    reward             | -0.09426112 |
# |    std                | 1.17        |
# |    value_loss         | 0.978       |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1656     |
# |    iterations         | 6300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 2.06     |
# |    reward             | 3.210471 |
# |    std                | 1.16     |
# |    value_loss         | 3.13     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1658      |
# |    iterations         | 6400      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -1.32     |
# |    reward             | 0.6131589 |
# |    std                | 1.18      |
# |    value_loss         | 1.82      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1661       |
# |    iterations         | 6500       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -1.6       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 0.975      |
# |    reward             | 0.63365954 |
# |    std                | 1.19       |
# |    value_loss         | 0.473      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1664      |
# |    iterations         | 6600      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | 5.54      |
# |    reward             | 1.5432434 |
# |    std                | 1.19      |
# |    value_loss         | 15.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1667       |
# |    iterations         | 6700       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -1.59      |
# |    explained_variance | -0.0219    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -7.16      |
# |    reward             | -3.1391666 |
# |    std                | 1.19       |
# |    value_loss         | 48.8       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1673        |
# |    iterations         | 6800        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 34000       |
# | train/                |             |
# |    entropy_loss       | -1.6        |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6799        |
# |    policy_loss        | -2.05       |
# |    reward             | -0.55542266 |
# |    std                | 1.2         |
# |    value_loss         | 18.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1675        |
# |    iterations         | 6900        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 34500       |
# | train/                |             |
# |    entropy_loss       | -1.61       |
# |    explained_variance | -0.0381     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6899        |
# |    policy_loss        | -9.76       |
# |    reward             | -0.80376965 |
# |    std                | 1.21        |
# |    value_loss         | 93          |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1679     |
# |    iterations         | 7000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | -0.0237  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -5.17    |
# |    reward             | 2.692145 |
# |    std                | 1.21     |
# |    value_loss         | 105      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1685       |
# |    iterations         | 7100       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 35500      |
# | train/                |            |
# |    entropy_loss       | -1.62      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7099       |
# |    policy_loss        | 5.93       |
# |    reward             | -2.1237612 |
# |    std                | 1.22       |
# |    value_loss         | 24.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1691       |
# |    iterations         | 7200       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -1.63      |
# |    explained_variance | -0.0317    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | 1.53       |
# |    reward             | -1.3549596 |
# |    std                | 1.23       |
# |    value_loss         | 1.86       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1697       |
# |    iterations         | 7300       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -1.62      |
# |    explained_variance | -0.0398    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | -5.75      |
# |    reward             | -5.0027003 |
# |    std                | 1.23       |
# |    value_loss         | 25.5       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1702     |
# |    iterations         | 7400     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -1.63    |
# |    explained_variance | -0.00478 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -1.78    |
# |    reward             | -0.63417 |
# |    std                | 1.23     |
# |    value_loss         | 2.33     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1708       |
# |    iterations         | 7500       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -1.62      |
# |    explained_variance | 0.112      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | -0.348     |
# |    reward             | -1.9797503 |
# |    std                | 1.23       |
# |    value_loss         | 0.296      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1713        |
# |    iterations         | 7600        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 38000       |
# | train/                |             |
# |    entropy_loss       | -1.61       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7599        |
# |    policy_loss        | 0.13        |
# |    reward             | -0.74566305 |
# |    std                | 1.21        |
# |    value_loss         | 0.0139      |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1719      |
# |    iterations         | 7700      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | 5.2       |
# |    reward             | 2.8047535 |
# |    std                | 1.2       |
# |    value_loss         | 22.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1724      |
# |    iterations         | 7800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | 2.31      |
# |    reward             | -1.307908 |
# |    std                | 1.19      |
# |    value_loss         | 4.44      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1730        |
# |    iterations         | 7900        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 39500       |
# | train/                |             |
# |    entropy_loss       | -1.59       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7899        |
# |    policy_loss        | -1.17       |
# |    reward             | -0.03466308 |
# |    std                | 1.19        |
# |    value_loss         | 1.78        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1736       |
# |    iterations         | 8000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -1.59      |
# |    explained_variance | -0.0273    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -2.37      |
# |    reward             | -1.2277187 |
# |    std                | 1.19       |
# |    value_loss         | 2.89       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1740      |
# |    iterations         | 8100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | -0.00237  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 6.31      |
# |    reward             | 0.7479467 |
# |    std                | 1.18      |
# |    value_loss         | 22.7      |
# -------------------------------------
# day: 1403, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1795099.37
# total_reward: 795099.37
# total_cost: 1855.77
# total_trades: 1394
# Sharpe: 0.458
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1745        |
# |    iterations         | 8200        |
# |    time_elapsed       | 23          |
# |    total_timesteps    | 41000       |
# | train/                |             |
# |    entropy_loss       | -1.6        |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8199        |
# |    policy_loss        | -9.03       |
# |    reward             | -0.15165737 |
# |    std                | 1.19        |
# |    value_loss         | 62          |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1750      |
# |    iterations         | 8300      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | -0.00856  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -3.62     |
# |    reward             | -2.308854 |
# |    std                | 1.2       |
# |    value_loss         | 3.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1754      |
# |    iterations         | 8400      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -1.61     |
# |    explained_variance | 0.00132   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -36.7     |
# |    reward             | -5.602435 |
# |    std                | 1.21      |
# |    value_loss         | 300       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1758       |
# |    iterations         | 8500       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 42500      |
# | train/                |            |
# |    entropy_loss       | -1.6       |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | -1.03      |
# |    reward             | 0.30212215 |
# |    std                | 1.2        |
# |    value_loss         | 1.05       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1762     |
# |    iterations         | 8600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.205    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -4.71    |
# |    reward             | 1.83853  |
# |    std                | 1.21     |
# |    value_loss         | 13       |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1767      |
# |    iterations         | 8700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -1.61     |
# |    explained_variance | -0.00111  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 2.11      |
# |    reward             | 2.7851076 |
# |    std                | 1.21      |
# |    value_loss         | 27.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1771     |
# |    iterations         | 8800     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 1.87     |
# |    reward             | 9.047741 |
# |    std                | 1.21     |
# |    value_loss         | 48.1     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1773       |
# |    iterations         | 8900       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -1.6       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | 0.705      |
# |    reward             | -2.7093368 |
# |    std                | 1.2        |
# |    value_loss         | 4.05       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1760       |
# |    iterations         | 9000       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -1.6       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | -0.474     |
# |    reward             | 0.11578922 |
# |    std                | 1.2        |
# |    value_loss         | 0.177      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1743        |
# |    iterations         | 9100        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 45500       |
# | train/                |             |
# |    entropy_loss       | -1.61       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9099        |
# |    policy_loss        | -0.776      |
# |    reward             | -0.59313995 |
# |    std                | 1.21        |
# |    value_loss         | 0.48        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1745        |
# |    iterations         | 9200        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 46000       |
# | train/                |             |
# |    entropy_loss       | -1.61       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9199        |
# |    policy_loss        | -0.127      |
# |    reward             | -0.30470634 |
# |    std                | 1.21        |
# |    value_loss         | 0.0933      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1738        |
# |    iterations         | 9300        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -1.62       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | -0.178      |
# |    reward             | -0.15281577 |
# |    std                | 1.22        |
# |    value_loss         | 0.0391      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1740       |
# |    iterations         | 9400       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -1.63      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | 0.659      |
# |    reward             | 0.30288115 |
# |    std                | 1.23       |
# |    value_loss         | 2.49       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1734      |
# |    iterations         | 9500      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -1.63     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | 1.65      |
# |    reward             | 2.5270562 |
# |    std                | 1.24      |
# |    value_loss         | 19.3      |
# -------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1730           |
# |    iterations         | 9600           |
# |    time_elapsed       | 27             |
# |    total_timesteps    | 48000          |
# | train/                |                |
# |    entropy_loss       | -1.63          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 9599           |
# |    policy_loss        | 3.14           |
# |    reward             | -0.00011336364 |
# |    std                | 1.24           |
# |    value_loss         | 5.05           |
# ------------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1733       |
# |    iterations         | 9700       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -1.63      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | -1.38      |
# |    reward             | -0.7453495 |
# |    std                | 1.23       |
# |    value_loss         | 2.8        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1737     |
# |    iterations         | 9800     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -1.62    |
# |    explained_variance | 0.0352   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | -4.05    |
# |    reward             | 2.393683 |
# |    std                | 1.22     |
# |    value_loss         | 10.4     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1738       |
# |    iterations         | 9900       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -1.63      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | 0.402      |
# |    reward             | 0.13540559 |
# |    std                | 1.23       |
# |    value_loss         | 0.137      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1739      |
# |    iterations         | 10000     |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -1.63     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 0.58      |
# |    reward             | 1.6960782 |
# |    std                | 1.24      |
# |    value_loss         | 0.171     |
# -------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# day: 1403, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1818495.54
# total_reward: 818495.54
# total_cost: 998.99
# total_trades: 1403
# Sharpe: 0.462
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 133       |
# |    time_elapsed    | 42        |
# |    total_timesteps | 5616      |
# | train/             |           |
# |    actor_loss      | 4.29e+03  |
# |    critic_loss     | 79        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5515      |
# |    reward          | 6.6292424 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 140       |
# |    time_elapsed    | 79        |
# |    total_timesteps | 11232     |
# | train/             |           |
# |    actor_loss      | 2.67e+03  |
# |    critic_loss     | 74.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11131     |
# |    reward          | 6.6292424 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 140       |
# |    time_elapsed    | 119       |
# |    total_timesteps | 16848     |
# | train/             |           |
# |    actor_loss      | 2.6e+03   |
# |    critic_loss     | 31.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16747     |
# |    reward          | 6.6292424 |
# ----------------------------------
# day: 1403, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1818495.54
# total_reward: 818495.54
# total_cost: 998.99
# total_trades: 1403
# Sharpe: 0.462
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 142       |
# |    time_elapsed    | 157       |
# |    total_timesteps | 22464     |
# | train/             |           |
# |    actor_loss      | 1.67e+03  |
# |    critic_loss     | 46.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22363     |
# |    reward          | 6.6292424 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 141       |
# |    time_elapsed    | 197       |
# |    total_timesteps | 28080     |
# | train/             |           |
# |    actor_loss      | 1.46e+03  |
# |    critic_loss     | 28.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27979     |
# |    reward          | 6.6292424 |
# ----------------------------------
# day: 1403, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1818495.54
# total_reward: 818495.54
# total_cost: 998.99
# total_trades: 1403
# Sharpe: 0.462
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 141       |
# |    time_elapsed    | 238       |
# |    total_timesteps | 33696     |
# | train/             |           |
# |    actor_loss      | 955       |
# |    critic_loss     | 672       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33595     |
# |    reward          | 6.6292424 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 141       |
# |    time_elapsed    | 277       |
# |    total_timesteps | 39312     |
# | train/             |           |
# |    actor_loss      | 577       |
# |    critic_loss     | 81.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39211     |
# |    reward          | 6.6292424 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 141       |
# |    time_elapsed    | 317       |
# |    total_timesteps | 44928     |
# | train/             |           |
# |    actor_loss      | 477       |
# |    critic_loss     | 36.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44827     |
# |    reward          | 6.6292424 |
# ----------------------------------
# day: 1403, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1818495.54
# total_reward: 818495.54
# total_cost: 998.99
# total_trades: 1403
# Sharpe: 0.462
# =================================

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None
# Out:
# --------------------------------------
# | time/              |               |
# |    fps             | 650           |
# |    iterations      | 1             |
# |    time_elapsed    | 3             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00026207013 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0028957701 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00482      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00266     |
# |    reward               | -0.028743522 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0315       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0023362853 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00922     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000256    |
# |    reward               | 0.013426706  |
# |    std                  | 1.02         |
# |    value_loss           | 0.0111       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 4             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00043017868 |
# |    clip_fraction        | 0.00229       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0123       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | 0.000207      |
# |    reward               | -0.0065205507 |
# |    std                  | 1.02          |
# |    value_loss           | 0.00663       |
# -------------------------------------------
# day: 1403, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 980681.88
# total_reward: -19318.12
# total_cost: 1394.18
# total_trades: 1325
# Sharpe: -0.341
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 448          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019004501 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0118      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000541    |
# |    reward               | 0.0050708405 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00776      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 441           |
# |    iterations           | 6             |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.004110478   |
# |    clip_fraction        | 0.0221        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0101        |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00175      |
# |    reward               | -0.0035178694 |
# |    std                  | 1.03          |
# |    value_loss           | 0.0265        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 7            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0058207195 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0243       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00208     |
# |    reward               | -0.59152156  |
# |    std                  | 1.03         |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 8           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004145453 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0878      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00105    |
# |    reward               | -0.07579676 |
# |    std                  | 1.02        |
# |    value_loss           | 0.511       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 9            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.004150518  |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.174        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00055     |
# |    reward               | -0.004610231 |
# |    std                  | 1.02         |
# |    value_loss           | 0.608        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 416           |
# |    iterations           | 10            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.0059557008  |
# |    clip_fraction        | 0.0443        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.00482       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00309      |
# |    reward               | -0.0011386515 |
# |    std                  | 1.02          |
# |    value_loss           | 0.0329        |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 11          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.001858874 |
# |    clip_fraction        | 0.0085      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.166       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00108    |
# |    reward               | -0.05718513 |
# |    std                  | 1.02        |
# |    value_loss           | 0.579       |
# -----------------------------------------
# day: 1403, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1032561.56
# total_reward: 32561.56
# total_cost: 1455.70
# total_trades: 1395
# Sharpe: 0.254
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 12           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0010650572 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.631        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 2.63e-05     |
# |    reward               | 0.092677444  |
# |    std                  | 1.02         |
# |    value_loss           | 1.55         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 409           |
# |    iterations           | 13            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00048941467 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.102         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 2.86e-05      |
# |    reward               | 0.054050002   |
# |    std                  | 1.03          |
# |    value_loss           | 0.241         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 341           |
# |    iterations           | 14            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00092612824 |
# |    clip_fraction        | 0.000684      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.183         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000133     |
# |    reward               | 0.3193736     |
# |    std                  | 1.04          |
# |    value_loss           | 0.514         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 15          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005077651 |
# |    clip_fraction        | 0.0226      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.356       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00256    |
# |    reward               | -0.09170932 |
# |    std                  | 1.03        |
# |    value_loss           | 0.539       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 16          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001761436 |
# |    clip_fraction        | 0.00332     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0648      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000426   |
# |    reward               | 0.36404768  |
# |    std                  | 1.04        |
# |    value_loss           | 0.258       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 17           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0017029308 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.132        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000434    |
# |    reward               | -0.006946019 |
# |    std                  | 1.04         |
# |    value_loss           | 0.182        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 18           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 8.679606e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0181       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000114     |
# |    reward               | 0.0013991568 |
# |    std                  | 1.04         |
# |    value_loss           | 0.0339       |
# ------------------------------------------
# day: 1403, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1022296.71
# total_reward: 22296.71
# total_cost: 1452.21
# total_trades: 1361
# Sharpe: 0.198
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 19           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035046288 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.000155    |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00101     |
# |    reward               | -0.02808066  |
# |    std                  | 1.05         |
# |    value_loss           | 0.031        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 20            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00040424874 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0731        |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -3.92e-05     |
# |    reward               | 0.002305729   |
# |    std                  | 1.06          |
# |    value_loss           | 0.0925        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 21           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0029910575 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0965       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000841    |
# |    reward               | 0.0019029102 |
# |    std                  | 1.06         |
# |    value_loss           | 0.261        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 22           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0003512805 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0517       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000128    |
# |    reward               | 0.00637585   |
# |    std                  | 1.05         |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 23           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0009602752 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0252       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000157    |
# |    reward               | 0.034377504  |
# |    std                  | 1.06         |
# |    value_loss           | 0.096        |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 254            |
# |    iterations           | 24             |
# |    time_elapsed         | 192            |
# |    total_timesteps      | 49152          |
# | train/                  |                |
# |    approx_kl            | 0.0009920483   |
# |    clip_fraction        | 4.88e-05       |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.48          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | 0.0429         |
# |    n_updates            | 230            |
# |    policy_gradient_loss | -0.000156      |
# |    reward               | -0.00088547706 |
# |    std                  | 1.07           |
# |    value_loss           | 0.0878         |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 25           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0011715875 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.32         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000549    |
# |    reward               | -0.08978191  |
# |    std                  | 1.08         |
# |    value_loss           | 0.464        |
# ------------------------------------------
# day: 1403, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1102415.11
# total_reward: 102415.11
# total_cost: 1489.88
# total_trades: 1381
# Sharpe: 0.378
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 248          |
# |    iterations           | 26           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0013116535 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.244        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000397    |
# |    reward               | -0.7592047   |
# |    std                  | 1.09         |
# |    value_loss           | 0.69         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 27           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0023049503 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.748        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000708    |
# |    reward               | 0.061435893  |
# |    std                  | 1.08         |
# |    value_loss           | 0.78         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 245           |
# |    iterations           | 28            |
# |    time_elapsed         | 233           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00039382142 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0859        |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -7.04e-05     |
# |    reward               | 0.11783705    |
# |    std                  | 1.08          |
# |    value_loss           | 0.182         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 29          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.00642339  |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.142       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00263    |
# |    reward               | -0.02116296 |
# |    std                  | 1.07        |
# |    value_loss           | 0.228       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 30           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0044251904 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00109      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00142     |
# |    reward               | 0.0005958785 |
# |    std                  | 1.07         |
# |    value_loss           | 0.0563       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 31            |
# |    time_elapsed         | 261           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.004841879   |
# |    clip_fraction        | 0.0137        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.49         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.000802      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00089      |
# |    reward               | -0.0139750885 |
# |    std                  | 1.07          |
# |    value_loss           | 0.0291        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 32           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0069762906 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0174      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00515     |
# |    reward               | -0.024491357 |
# |    std                  | 1.06         |
# |    value_loss           | 0.00547      |
# ------------------------------------------
# day: 1403, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 1026596.08
# total_reward: 26596.08
# total_cost: 1491.40
# total_trades: 1378
# Sharpe: 0.365
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 245            |
# |    iterations           | 33             |
# |    time_elapsed         | 274            |
# |    total_timesteps      | 67584          |
# | train/                  |                |
# |    approx_kl            | 0.002558967    |
# |    clip_fraction        | 0.00273        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.48          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | 0.00937        |
# |    n_updates            | 320            |
# |    policy_gradient_loss | -0.000541      |
# |    reward               | -3.4230103e-05 |
# |    std                  | 1.06           |
# |    value_loss           | 0.0469         |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 34            |
# |    time_elapsed         | 286           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00074417924 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0041       |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000103     |
# |    reward               | 0.0033613471  |
# |    std                  | 1.07          |
# |    value_loss           | 0.0174        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 35           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0032727094 |
# |    clip_fraction        | 0.00239      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0174      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00073     |
# |    reward               | 0.0029798718 |
# |    std                  | 1.06         |
# |    value_loss           | 0.00543      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 36           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0006925652 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00969     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000124    |
# |    reward               | 0.0039757118 |
# |    std                  | 1.06         |
# |    value_loss           | 0.00785      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 37           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.00356691   |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0296      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000792    |
# |    reward               | 0.0029144625 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00185      |
# ------------------------------------------
# ---------------------------------------------
# | time/                   |                 |
# |    fps                  | 219             |
# |    iterations           | 38              |
# |    time_elapsed         | 354             |
# |    total_timesteps      | 77824           |
# | train/                  |                 |
# |    approx_kl            | 0.0008868438    |
# |    clip_fraction        | 0.000586        |
# |    clip_range           | 0.2             |
# |    entropy_loss         | -1.47           |
# |    explained_variance   | 5.96e-08        |
# |    learning_rate        | 0.00025         |
# |    loss                 | -0.0144         |
# |    n_updates            | 370             |
# |    policy_gradient_loss | -6.13e-05       |
# |    reward               | -0.000111591406 |
# |    std                  | 1.06            |
# |    value_loss           | 0.000911        |
# ---------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 39           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.004623981  |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0164      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0031      |
# |    reward               | 0.0050171004 |
# |    std                  | 1.06         |
# |    value_loss           | 0.000924     |
# ------------------------------------------
# day: 1403, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1000923.30
# total_reward: 923.30
# total_cost: 919.95
# total_trades: 998
# Sharpe: 0.147
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 204            |
# |    iterations           | 40             |
# |    time_elapsed         | 400            |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | 0.005103203    |
# |    clip_fraction        | 0.037          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.47          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.00485       |
# |    n_updates            | 390            |
# |    policy_gradient_loss | -0.00275       |
# |    reward               | -0.00020384636 |
# |    std                  | 1.05           |
# |    value_loss           | 0.000475       |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 41           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0019868524 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0135      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00036     |
# |    reward               | 0.004158111  |
# |    std                  | 1.06         |
# |    value_loss           | 0.000395     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 42           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0044253934 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00551     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00164     |
# |    reward               | 0.0005617417 |
# |    std                  | 1.05         |
# |    value_loss           | 0.000289     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 187           |
# |    iterations           | 43            |
# |    time_elapsed         | 468           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.0038601821  |
# |    clip_fraction        | 0.0159        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0253       |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00123      |
# |    reward               | -7.703672e-05 |
# |    std                  | 1.05          |
# |    value_loss           | 0.000189      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 44          |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004314015 |
# |    clip_fraction        | 0.00923     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0262     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000571   |
# |    reward               | 0.0         |
# |    std                  | 1.05        |
# |    value_loss           | 0.000352    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 182           |
# |    iterations           | 45            |
# |    time_elapsed         | 505           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.004837286   |
# |    clip_fraction        | 0.0578        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0175       |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00331      |
# |    reward               | -0.0038487685 |
# |    std                  | 1.05          |
# |    value_loss           | 0.000292      |
# -------------------------------------------
# day: 1403, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 998151.67
# total_reward: -1848.33
# total_cost: 665.06
# total_trades: 742
# Sharpe: -0.514
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 177            |
# |    iterations           | 46             |
# |    time_elapsed         | 531            |
# |    total_timesteps      | 94208          |
# | train/                  |                |
# |    approx_kl            | 0.0021237708   |
# |    clip_fraction        | 0.00483        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.47          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.014         |
# |    n_updates            | 450            |
# |    policy_gradient_loss | -0.000168      |
# |    reward               | -0.00024306557 |
# |    std                  | 1.06           |
# |    value_loss           | 0.000483       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 47            |
# |    time_elapsed         | 544           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.0043134643  |
# |    clip_fraction        | 0.0314        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0174       |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.00186      |
# |    reward               | -5.381169e-06 |
# |    std                  | 1.05          |
# |    value_loss           | 0.000128      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 175           |
# |    iterations           | 48            |
# |    time_elapsed         | 559           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.0021766508  |
# |    clip_fraction        | 0.0294        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00791      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.00198      |
# |    reward               | -9.721618e-05 |
# |    std                  | 1.05          |
# |    value_loss           | 6.58e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 178          |
# |    iterations           | 49           |
# |    time_elapsed         | 563          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0017698414 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0214      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -4.37e-05    |
# |    reward               | 0.0007386031 |
# |    std                  | 1.05         |
# |    value_loss           | 0.000118     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 180          |
# |    iterations           | 50           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0047080927 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0254      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00233     |
# |    reward               | 0.0          |
# |    std                  | 1.06         |
# |    value_loss           | 0.000213     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 51           |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0033160837 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0166      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00124     |
# |    reward               | 0.0          |
# |    std                  | 1.05         |
# |    value_loss           | 3.06e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 185          |
# |    iterations           | 52           |
# |    time_elapsed         | 573          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0025873538 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0169      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -7.83e-05    |
# |    reward               | 0.017284423  |
# |    std                  | 1.05         |
# |    value_loss           | 7.43e-05     |
# ------------------------------------------
# day: 1403, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 1001421.73
# total_reward: 1421.73
# total_cost: 473.26
# total_trades: 633
# Sharpe: 0.542
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 53           |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0017511669 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0206      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 3.07e-05     |
# |    reward               | 0.0          |
# |    std                  | 1.05         |
# |    value_loss           | 4.84e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 54           |
# |    time_elapsed         | 578          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0029776897 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0222      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000312    |
# |    reward               | 0.0          |
# |    std                  | 1.05         |
# |    value_loss           | 0.000111     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 55           |
# ...
# total_trades: 432
# Sharpe: -0.196
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 81           |
# |    time_elapsed         | 649          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0023670346 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0121      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | 0.001531119  |
# |    std                  | 0.967        |
# |    value_loss           | 3.2e-05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 82          |
# |    time_elapsed         | 651         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.006989375 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00489    |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00385    |
# |    reward               | 0.0         |
# |    std                  | 0.966       |
# |    value_loss           | 4.47e-05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 259           |
# |    iterations           | 83            |
# |    time_elapsed         | 654           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.004631482   |
# |    clip_fraction        | 0.0282        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00916      |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -0.00224      |
# |    reward               | 0.00029216154 |
# |    std                  | 0.961         |
# |    value_loss           | 8.88e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 261          |
# |    iterations           | 84           |
# |    time_elapsed         | 658          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0022995714 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000233     |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.000888    |
# |    reward               | 0.0          |
# |    std                  | 0.963        |
# |    value_loss           | 7.41e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 85           |
# |    time_elapsed         | 660          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0059732674 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0147      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00311     |
# |    reward               | 0.0018689685 |
# |    std                  | 0.965        |
# |    value_loss           | 4.1e-05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 265          |
# |    iterations           | 86           |
# |    time_elapsed         | 663          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0033375784 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00446     |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00125     |
# |    reward               | -0.000129264 |
# |    std                  | 0.964        |
# |    value_loss           | 4.02e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 267           |
# |    iterations           | 87            |
# |    time_elapsed         | 665           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 5.5326178e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0139       |
# |    n_updates            | 860           |
# |    policy_gradient_loss | 8.29e-05      |
# |    reward               | 0.0           |
# |    std                  | 0.957         |
# |    value_loss           | 7.26e-05      |
# -------------------------------------------
# day: 1403, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1000504.32
# total_reward: 504.32
# total_cost: 331.52
# total_trades: 449
# Sharpe: 0.413
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 88          |
# |    time_elapsed         | 667         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.004305945 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0193     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00291    |
# |    reward               | 0.0         |
# |    std                  | 0.959       |
# |    value_loss           | 6.91e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 89           |
# |    time_elapsed         | 669          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0047200667 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.005        |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00139     |
# |    reward               | 0.0          |
# |    std                  | 0.959        |
# |    value_loss           | 3.63e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 274           |
# |    iterations           | 90            |
# |    time_elapsed         | 672           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.002286539   |
# |    clip_fraction        | 0.0114        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00326      |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -0.000801     |
# |    reward               | 0.00049464585 |
# |    std                  | 0.967         |
# |    value_loss           | 2.46e-05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 91            |
# |    time_elapsed         | 674           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00052093924 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0152       |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 0.000148      |
# |    reward               | 0.0           |
# |    std                  | 0.965         |
# |    value_loss           | 3.76e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 92           |
# |    time_elapsed         | 677          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0025788744 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0161      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.000261    |
# |    reward               | 0.0          |
# |    std                  | 0.971        |
# |    value_loss           | 1.92e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 93          |
# |    time_elapsed         | 679         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.004059655 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0238     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00203    |
# |    reward               | 0.0         |
# |    std                  | 0.965       |
# |    value_loss           | 5.87e-05    |
# -----------------------------------------
# day: 1403, episode: 210
# begin_total_asset: 1000000.00
# end_total_asset: 999435.22
# total_reward: -564.78
# total_cost: 191.76
# total_trades: 251
# Sharpe: -0.471
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 94            |
# |    time_elapsed         | 681           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00028598483 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00825      |
# |    n_updates            | 930           |
# |    policy_gradient_loss | -0.000188     |
# |    reward               | 0.0           |
# |    std                  | 0.979         |
# |    value_loss           | 1.63e-05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 284           |
# |    iterations           | 95            |
# |    time_elapsed         | 684           |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 0.0027485192  |
# |    clip_fraction        | 0.00942       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0137       |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -0.000807     |
# |    reward               | -7.540743e-05 |
# |    std                  | 0.977         |
# |    value_loss           | 1.98e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 96           |
# |    time_elapsed         | 686          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0033807855 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00853     |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00105     |
# |    reward               | 0.0          |
# |    std                  | 0.975        |
# |    value_loss           | 6.88e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 97           |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0015255406 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0166      |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.000151     |
# |    reward               | 0.0          |
# |    std                  | 0.977        |
# |    value_loss           | 1.1e-05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 98           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0008692901 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0195      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00021     |
# |    reward               | 0.0          |
# |    std                  | 0.981        |
# |    value_loss           | 1.5e-05      |
# ------------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# day: 1403, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 44       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 5616     |
# | train/             |          |
# |    actor_loss      | 8.2e+03  |
# |    critic_loss     | 3.91e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5515     |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 42       |
# |    time_elapsed    | 262      |
# |    total_timesteps | 11232    |
# | train/             |          |
# |    actor_loss      | 1.28e+04 |
# |    critic_loss     | 968      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11131    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 42       |
# |    time_elapsed    | 401      |
# |    total_timesteps | 16848    |
# | train/             |          |
# |    actor_loss      | 1.1e+04  |
# |    critic_loss     | 4.53e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16747    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 43       |
# |    time_elapsed    | 513      |
# |    total_timesteps | 22464    |
# | train/             |          |
# |    actor_loss      | 9.36e+03 |
# |    critic_loss     | 2.91e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22363    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 48       |
# |    time_elapsed    | 574      |
# |    total_timesteps | 28080    |
# | train/             |          |
# |    actor_loss      | 8.04e+03 |
# |    critic_loss     | 391      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27979    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 240
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 52       |
# |    time_elapsed    | 636      |
# |    total_timesteps | 33696    |
# | train/             |          |
# |    actor_loss      | 7.51e+03 |
# |    critic_loss     | 400      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 33595    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 56       |
# |    time_elapsed    | 697      |
# |    total_timesteps | 39312    |
# | train/             |          |
# |    actor_loss      | 6.41e+03 |
# |    critic_loss     | 1.04e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39211    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 59       |
# |    time_elapsed    | 759      |
# |    total_timesteps | 44928    |
# | train/             |          |
# |    actor_loss      | 5.44e+03 |
# |    critic_loss     | 6.42e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44827    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 250
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None
# Out:
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 78       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 5616     |
# | train/             |          |
# |    actor_loss      | 2.5e+04  |
# |    critic_loss     | 2.11e+04 |
# |    ent_coef        | 0.174    |
# |    ent_coef_loss   | 16.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5515     |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 81       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 11232    |
# | train/             |          |
# |    actor_loss      | 1.89e+04 |
# |    critic_loss     | 947      |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | 11.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11131    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 70       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 16848    |
# | train/             |          |
# |    actor_loss      | 1.42e+04 |
# |    critic_loss     | 3.13e+04 |
# |    ent_coef        | 0.534    |
# |    ent_coef_loss   | 5.87     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16747    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 55       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 22464    |
# | train/             |          |
# |    actor_loss      | 1.06e+04 |
# |    critic_loss     | 2.09e+03 |
# |    ent_coef        | 0.936    |
# |    ent_coef_loss   | 0.625    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22363    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 270
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 64       |
# |    time_elapsed    | 433      |
# |    total_timesteps | 28080    |
# | train/             |          |
# |    actor_loss      | 8.27e+03 |
# |    critic_loss     | 1.2e+04  |
# |    ent_coef        | 1.64     |
# |    ent_coef_loss   | -4.65    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27979    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 72       |
# |    time_elapsed    | 464      |
# |    total_timesteps | 33696    |
# | train/             |          |
# |    actor_loss      | 6.63e+03 |
# |    critic_loss     | 1.65e+04 |
# |    ent_coef        | 2.88     |
# |    ent_coef_loss   | -9.8     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33595    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 79       |
# |    time_elapsed    | 491      |
# |    total_timesteps | 39312    |
# | train/             |          |
# |    actor_loss      | 6.04e+03 |
# |    critic_loss     | 6.95e+03 |
# |    ent_coef        | 5.04     |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 39211    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 85       |
# |    time_elapsed    | 523      |
# |    total_timesteps | 44928    |
# | train/             |          |
# |    actor_loss      | 6.4e+03  |
# |    critic_loss     | 7.17e+04 |
# |    ent_coef        | 8.85     |
# |    ent_coef_loss   | -20.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 44827    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 91       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 50544    |
# | train/             |          |
# |    actor_loss      | 7.93e+03 |
# |    critic_loss     | 3.12e+04 |
# |    ent_coef        | 15.5     |
# |    ent_coef_loss   | -26      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 50443    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 290
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 94       |
# |    time_elapsed    | 591      |
# |    total_timesteps | 56160    |
# | train/             |          |
# |    actor_loss      | 1.15e+04 |
# |    critic_loss     | 4.06e+04 |
# |    ent_coef        | 27.2     |
# |    ent_coef_loss   | -31.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56059    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 97       |
# |    time_elapsed    | 630      |
# |    total_timesteps | 61776    |
# | train/             |          |
# |    actor_loss      | 1.82e+04 |
# |    critic_loss     | 1.38e+03 |
# |    ent_coef        | 47.7     |
# |    ent_coef_loss   | -36.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61675    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1403, episode: 300
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 100      |
# |    time_elapsed    | 670      |
# |    total_timesteps | 67392    |
# | train/             |          |
# |    actor_loss      | 3.1e+04  |
# |    critic_loss     | 1.91e+04 |
# |    ent_coef        | 83.6     |
# |    ent_coef_loss   | -42.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 67291    |
# |    reward          | 0.0      |
# ---------------------------------

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## Save the trained agent
# Trained agents should have already been saved in the "trained_models" drectory after you run the code blocks above.
#
# For Colab users, the zip files should be at "./trained_models" or "/content/trained_models".
#
# For users running on your local environment, the zip files should be at "./trained_models".
