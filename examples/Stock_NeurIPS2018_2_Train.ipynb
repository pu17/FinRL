# %% [markdown]
# # Stock NeurIPS2018 Part 2. Train
# This series is a reproduction of *the process in the paper Practical Deep Reinforcement Learning Approach for Stock Trading*.
#
# This is the second part of the NeurIPS2018 series, introducing how to use FinRL to make data into the gym form environment, and train DRL agents on it.
#
# Other demos can be found at the repo of [FinRL-Tutorials]((https://github.com/AI4Finance-Foundation/FinRL-Tutorials)).

# %% [markdown]
# # Part 1. Install Packages

# %%
## install finrl library
#!pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
from stable_baselines3.common.logger import configure

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# # Part 2. Build A Market Environment in OpenAI Gym-style

# %% [markdown]
# ![rl_diagram_transparent_bg.png](data:image/png;base64,...)

# %% [markdown]
# The core element in reinforcement learning are **agent** and **environment**. You can understand RL as the following process:
#
# The agent is active in a world, which is the environment. It observe its current condition as a **state**, and is allowed to do certain **actions**. After the agent execute an action, it will arrive at a new state. At the same time, the environment will have feedback to the agent called **reward**, a numerical signal that tells how good or bad the new state is. As the figure above, agent and environment will keep doing this interaction.
#
# The goal of agent is to get as much cumulative reward as possible. Reinforcement learning is the method that agent learns to improve its behavior and achieve that goal.

# %% [markdown]
# To achieve this in Python, we follow the OpenAI gym style to build the stock data into environment.
#
# state-action-reward are specified as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes the price data and technical indicators based on the past data. It will learn by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 constituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.

# %% [markdown]
# ## Read data
#
# We first read the .csv file of our training data into dataframe.

# %%
train = pd.read_csv('train_data.csv')

# If you are not using the data generated from part 1 of this tutorial, make sure 
# it has the columns and index in the form that could be make into the environment. 
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']

# %% [markdown]
# ## Construct the environment

# %% [markdown]
# Calculate and specify the parameters we need for constructing the environment.

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 3: Train DRL Agents
# * Here, the DRL algorithms are from **[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)**. It's a library that implemented popular DRL algorithms using pytorch, succeeding to its old version: Stable Baselines.
# * Users are also encouraged to try **[ElegantRL](https://github.com/AI4Finance-Foundation/ElegantRL)** and **[Ray RLlib](https://github.com/ray-project/ray)**.

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ## Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# --------------------------------------
# | time/                 |            |
# |    fps                | 1354       |
# |    iterations         | 100        |
# |    time_elapsed       | 0          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | 0.0402     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 5.85       |
# |    reward             | -2.6487741 |
# |    std                | 0.99       |
# |    value_loss         | 10.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1534       |
# |    iterations         | 200        |
# |    time_elapsed       | 0          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.8       |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 5.93       |
# |    reward             | 0.34167847 |
# |    std                | 0.984      |
# |    value_loss         | 3.89       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1529       |
# |    iterations         | 300        |
# |    time_elapsed       | 0          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.81      |
# |    explained_variance | -0.0156    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 1.26       |
# |    reward             | -1.1224039 |
# |    std                | 0.985      |
# |    value_loss         | 0.894      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1558        |
# |    iterations         | 400         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -2.8        |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 2.29        |
# |    reward             | -0.08737793 |
# |    std                | 0.979       |
# |    value_loss         | 1.18        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1576       |
# |    iterations         | 500        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.79      |
# |    explained_variance | -0.0509    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 3.52       |
# |    reward             | -1.1886067 |
# |    std                | 0.978      |
# |    value_loss         | 2.54       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1616        |
# |    iterations         | 600         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.79       |
# |    explained_variance | 0.0947      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -1.06       |
# |    reward             | -0.99858654 |
# |    std                | 0.976       |
# |    value_loss         | 0.994       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1637        |
# |    iterations         | 700         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -2.77       |
# |    explained_variance | -2.03       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 4.79        |
# |    reward             | -0.24284488 |
# |    std                | 0.966       |
# |    value_loss         | 2.09        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1647        |
# |    iterations         | 800         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -2.76       |
# |    explained_variance | 0.14        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 2.12        |
# |    reward             | -0.85332763 |
# |    std                | 0.962       |
# |    value_loss         | 1           |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1667      |
# |    iterations         | 900       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.77     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -11.3     |
# |    reward             | 2.4533617 |
# |    std                | 0.966     |
# |    value_loss         | 36.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1666     |
# |    iterations         | 1000     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -2.78    |
# |    explained_variance | 0.0129   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -14.1    |
# |    reward             | 2.164129 |
# |    std                | 0.974    |
# |    value_loss         | 59.2     |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1678         |
# |    iterations         | 1100         |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -2.8         |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | -0.667       |
# |    reward             | -0.046526708 |
# |    std                | 0.985        |
# |    value_loss         | 1.49         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1691      |
# |    iterations         | 1200      |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -1.88     |
# |    reward             | 1.5552354 |
# |    std                | 0.991     |
# |    value_loss         | 1.27      |
# -------------------------------------
# day: 702, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1447293.29
# total_reward: 447293.29
# total_cost: 3473.90
# total_trades: 769
# Sharpe: 0.816
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 1678       |
# |    iterations         | 1300       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -0.724     |
# |    reward             | 0.32520464 |
# |    std                | 0.99       |
# |    value_loss         | 0.305      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1689        |
# |    iterations         | 1400        |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -2.83       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 3.06        |
# |    reward             | -0.65474415 |
# |    std                | 0.996       |
# |    value_loss         | 1.24        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1683      |
# |    iterations         | 1500      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 2.98      |
# |    reward             | 0.9903297 |
# |    std                | 1         |
# |    value_loss         | 1.96      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1681       |
# |    iterations         | 1600       |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -0.288     |
# |    reward             | 0.86546296 |
# |    std                | 1          |
# |    value_loss         | 0.987      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1691      |
# |    iterations         | 1700      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 2.33      |
# |    reward             | 2.9869452 |
# |    std                | 0.999     |
# |    value_loss         | 2.27      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1701       |
# |    iterations         | 1800       |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -2.83      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 6.29       |
# |    reward             | 0.35221326 |
# |    std                | 0.999      |
# |    value_loss         | 10.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1709      |
# |    iterations         | 1900      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 0.0159    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -19.5     |
# |    reward             | -5.082345 |
# |    std                | 0.994     |
# |    value_loss         | 45.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1714      |
# |    iterations         | 2000      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.798    |
# |    reward             | 0.9804558 |
# |    std                | 0.991     |
# |    value_loss         | 0.375     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1721       |
# |    iterations         | 2100       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | 0.00344    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 0.995      |
# |    reward             | -1.5470012 |
# |    std                | 0.991      |
# |    value_loss         | 0.272      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1727       |
# |    iterations         | 2200       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -2.83      |
# |    explained_variance | -0.115     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -2.48      |
# |    reward             | -0.0901983 |
# |    std                | 0.997      |
# |    value_loss         | 1.45       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1733       |
# |    iterations         | 2300       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -29.6      |
# |    reward             | 0.57329863 |
# |    std                | 1          |
# |    value_loss         | 143        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1739       |
# |    iterations         | 2400       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -0.0899    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 8.14       |
# |    reward             | -2.4324932 |
# |    std                | 1.02       |
# |    value_loss         | 7.34       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1744       |
# |    iterations         | 2500       |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | -0.017     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -1.37      |
# |    reward             | -1.2918675 |
# |    std                | 1.01       |
# |    value_loss         | 0.34       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1748      |
# |    iterations         | 2600      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 2.56      |
# |    reward             | 2.5706077 |
# |    std                | 1.01      |
# |    value_loss         | 1.24      |
# -------------------------------------
# day: 702, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1436234.43
# total_reward: 436234.43
# total_cost: 76851.47
# total_trades: 1006
# Sharpe: 0.806
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 1750       |
# |    iterations         | 2700       |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -4.85      |
# |    reward             | 0.31598878 |
# |    std                | 1.01       |
# |    value_loss         | 4.12       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1755      |
# |    iterations         | 2800      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.104     |
# |    reward             | 1.2592554 |
# |    std                | 1.01      |
# |    value_loss         | 0.918     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1758      |
# |    iterations         | 2900      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.212    |
# |    reward             | 1.4556963 |
# |    std                | 1.01      |
# |    value_loss         | 0.919     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1761      |
# |    iterations         | 3000      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 5.13      |
# |    reward             | 1.1027671 |
# |    std                | 1         |
# |    value_loss         | 6.75      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1764      |
# |    iterations         | 3100      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 23        |
# |    reward             | 1.3327705 |
# |    std                | 1.01      |
# |    value_loss         | 66.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1767      |
# |    iterations         | 3200      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -6.44     |
# |    reward             | 2.0371974 |
# |    std                | 1         |
# |    value_loss         | 6.71      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1770       |
# |    iterations         | 3300       |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 4.66       |
# |    reward             | 0.72080386 |
# |    std                | 0.999      |
# |    value_loss         | 5.92       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1773      |
# |    iterations         | 3400      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.622    |
# |    reward             | 0.2836073 |
# |    std                | 1         |
# |    value_loss         | 0.546     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1776      |
# |    iterations         | 3500      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.1       |
# |    reward             | 3.7469742 |
# |    std                | 1         |
# |    value_loss         | 0.834     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1778        |
# |    iterations         | 3600        |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -2.84       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3599        |
# |    policy_loss        | -7.79       |
# |    reward             | 0.023427613 |
# |    std                | 1           |
# |    value_loss         | 7.19        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1780      |
# |    iterations         | 3700      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.39      |
# |    reward             | 1.4983447 |
# |    std                | 1.01      |
# |    value_loss         | 0.542     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1782      |
# |    iterations         | 3800      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0.0371    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 1.61      |
# |    reward             | 1.3396645 |
# |    std                | 1.01      |
# |    value_loss         | 0.546     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1785        |
# |    iterations         | 3900        |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 19500       |
# | train/                |             |
# |    entropy_loss       | -2.85       |
# |    explained_variance | 0.292       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3899        |
# |    policy_loss        | 1.75        |
# |    reward             | -0.16587648 |
# |    std                | 1.01        |
# |    value_loss         | 0.626       |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1776     |
# |    iterations         | 4000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | 0.0196   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 2        |
# |    reward             | 0.274184 |
# |    std                | 1.01     |
# |    value_loss         | 1.5      |
# ------------------------------------
# day: 702, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1369107.61
# total_reward: 369107.61
# total_cost: 20589.60
# total_trades: 780
# Sharpe: 0.718
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1778        |
# |    iterations         | 4100        |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | 0.0343      |
# |    reward             | -0.16563198 |
# |    std                | 1.02        |
# |    value_loss         | 0.28        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1780       |
# |    iterations         | 4200       |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | 3.24       |
# |    reward             | 0.03972949 |
# |    std                | 1.02       |
# |    value_loss         | 1.13       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1782      |
# |    iterations         | 4300      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | -0.0287   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -9.45     |
# |    reward             | 3.1100097 |
# |    std                | 1.02      |
# |    value_loss         | 9.41      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1784      |
# |    iterations         | 4400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | -0.0932   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -0.569    |
# |    reward             | 0.7831014 |
# |    std                | 1.03      |
# |    value_loss         | 0.215     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1786        |
# |    iterations         | 4500        |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 22500       |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | 0.103       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4499        |
# |    policy_loss        | 0.221       |
# |    reward             | -0.35788238 |
# |    std                | 1.04        |
# |    value_loss         | 0.375       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1788       |
# |    iterations         | 4600       |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | -0.0043    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | -6.06      |
# |    reward             | -2.4617834 |
# |    std                | 1.03       |
# |    value_loss         | 5.21       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1785        |
# |    iterations         | 4700        |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | 0.014       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | -1.11       |
# |    reward             | -0.04885288 |
# |    std                | 1.02        |
# |    value_loss         | 0.509       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1783        |
# |    iterations         | 4800        |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -2.9        |
# |    explained_variance | -0.0499     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | -3.38       |
# |    reward             | 0.025729045 |
# |    std                | 1.03        |
# |    value_loss         | 2.84        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1780       |
# |    iterations         | 4900       |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0.000227   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -0.977     |
# |    reward             | -2.8621187 |
# |    std                | 1.04       |
# |    value_loss         | 0.282      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1780       |
# |    iterations         | 5000       |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0.119      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -2.06      |
# |    reward             | 0.62359154 |
# |    std                | 1.04       |
# |    value_loss         | 0.714      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1781      |
# |    iterations         | 5100      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | -0.522    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 2.2       |
# |    reward             | 0.6656665 |
# |    std                | 1.04      |
# |    value_loss         | 0.765     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1783      |
# |    iterations         | 5200      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -2.91     |
# |    explained_variance | 0.00151   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 7.53      |
# |    reward             | 0.9506784 |
# |    std                | 1.04      |
# |    value_loss         | 6.47      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1784       |
# |    iterations         | 5300       |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 26500      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0.0403     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5299       |
# |    policy_loss        | -13.1      |
# |    reward             | -0.5716211 |
# |    std                | 1.04       |
# |    value_loss         | 13.5       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1785        |
# |    iterations         | 5400        |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 27000       |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | -0.00621    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5399        |
# |    policy_loss        | -10.4       |
# |    reward             | -0.94928825 |
# |    std                | 1.04        |
# |    value_loss         | 13.9        |
# ---------------------------------------
# day: 702, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1417511.74
# total_reward: 417511.74
# total_cost: 34893.20
# total_trades: 741
# Sharpe: 0.796
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1787      |
# |    iterations         | 5500      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -2.91     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -1.83     |
# |    reward             | 1.3933421 |
# |    std                | 1.04      |
# |    value_loss         | 2.27      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1788       |
# |    iterations         | 5600       |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | -0.0184    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | 5.63       |
# |    reward             | -2.6957707 |
# |    std                | 1.05       |
# |    value_loss         | 4.53       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1790       |
# |    iterations         | 5700       |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -3.01      |
# |    reward             | -1.6721581 |
# |    std                | 1.04       |
# |    value_loss         | 3.19       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1791      |
# |    iterations         | 5800      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | -0.0635   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -5.85     |
# |    reward             | 1.3106248 |
# |    std                | 1.05      |
# |    value_loss         | 3.94      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1792          |
# |    iterations         | 5900          |
# |    time_elapsed       | 16            |
# |    total_timesteps    | 29500         |
# | train/                |               |
# |    entropy_loss       | -2.92         |
# |    explained_variance | 0.00435       |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 5899          |
# |    policy_loss        | 0.804         |
# |    reward             | -0.0026846295 |
# |    std                | 1.04          |
# |    value_loss         | 0.422         |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1794        |
# |    iterations         | 6000        |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 30000       |
# | train/                |             |
# |    entropy_loss       | -2.93       |
# |    explained_variance | -0.00666    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5999        |
# |    policy_loss        | 11.1        |
# |    reward             | -0.37104994 |
# |    std                | 1.05        |
# |    value_loss         | 20.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1795       |
# |    iterations         | 6100       |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -2.94      |
# |    explained_variance | 0.0245     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -1.11      |
# |    reward             | -4.1048355 |
# |    std                | 1.05       |
# |    value_loss         | 4.47       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1796       |
# |    iterations         | 6200       |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | 0.0467     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -4.3       |
# |    reward             | -0.8645833 |
# |    std                | 1.05       |
# |    value_loss         | 3.56       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1798      |
# |    iterations         | 6300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -2.94     |
# |    explained_variance | 0.155     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -3.12     |
# |    reward             | 1.0802538 |
# |    std                | 1.06      |
# |    value_loss         | 1.15      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1798        |
# |    iterations         | 6400        |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 32000       |
# | train/                |             |
# |    entropy_loss       | -2.94       |
# |    explained_variance | -0.00756    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6399        |
# |    policy_loss        | 6.21        |
# |    reward             | -0.74235547 |
# |    std                | 1.06        |
# |    value_loss         | 10.9        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1798         |
# |    iterations         | 6500         |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 32500        |
# | train/                |              |
# |    entropy_loss       | -2.95        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 6499         |
# |    policy_loss        | 11.1         |
# |    reward             | -0.034927838 |
# |    std                | 1.06         |
# |    value_loss         | 13.9         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1799        |
# |    iterations         | 6600        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 33000       |
# | train/                |             |
# |    entropy_loss       | -2.96       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6599        |
# |    policy_loss        | -5.11       |
# |    reward             | -0.12560877 |
# |    std                | 1.07        |
# |    value_loss         | 3.32        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1800     |
# |    iterations         | 6700     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -6.16    |
# |    reward             | 3.789848 |
# |    std                | 1.05     |
# |    value_loss         | 7.55     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1801      |
# |    iterations         | 6800      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -2.93     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 10.5      |
# |    reward             | 0.6602636 |
# |    std                | 1.05      |
# |    value_loss         | 32        |
# -------------------------------------
# day: 702, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1878374.82
# total_reward: 878374.82
# total_cost: 14772.46
# total_trades: 1094
# Sharpe: 1.074
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1802     |
# |    iterations         | 6900     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 2.2      |
# |    reward             | 4.828099 |
# |    std                | 1.04     |
# |    value_loss         | 3.37     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1802       |
# |    iterations         | 7000       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | -2.56      |
# |    reward             | 0.44998783 |
# |    std                | 1.04       |
# |    value_loss         | 8.48       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1802     |
# |    iterations         | 7100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | -0.199   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 6.31     |
# |    reward             | 2.037055 |
# |    std                | 1.05     |
# |    value_loss         | 3.69     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1802       |
# |    iterations         | 7200       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | 1.37       |
# |    reward             | 0.12377256 |
# |    std                | 1.04       |
# |    value_loss         | 0.509      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1804       |
# |    iterations         | 7300       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | -10.9      |
# |    reward             | 0.58983874 |
# |    std                | 1.04       |
# |    value_loss         | 11.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1805       |
# |    iterations         | 7400       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | 3.44       |
# |    reward             | -0.6358566 |
# |    std                | 1.04       |
# |    value_loss         | 1.57       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1806       |
# |    iterations         | 7500       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | -2.28      |
# |    reward             | -0.6594552 |
# |    std                | 1.03       |
# |    value_loss         | 1.03       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1807       |
# |    iterations         | 7600       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 38000      |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7599       |
# |    policy_loss        | 6.5        |
# |    reward             | -5.3939967 |
# |    std                | 1.04       |
# |    value_loss         | 11.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1808       |
# |    iterations         | 7700       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 38500      |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7699       |
# |    policy_loss        | 0.523      |
# |    reward             | 0.35786268 |
# |    std                | 1.03       |
# |    value_loss         | 0.781      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1809       |
# |    iterations         | 7800       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | 0.996      |
# |    reward             | -1.1706109 |
# |    std                | 1.03       |
# |    value_loss         | 0.133      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1810       |
# |    iterations         | 7900       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 39500      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | -0.0827    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7899       |
# |    policy_loss        | 2.98       |
# |    reward             | -0.9442014 |
# |    std                | 1.04       |
# |    value_loss         | 0.998      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1811       |
# |    iterations         | 8000       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | 2.08       |
# |    reward             | 0.30212027 |
# |    std                | 1.04       |
# |    value_loss         | 1.7        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1812        |
# |    iterations         | 8100        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 40500       |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8099        |
# |    policy_loss        | -4.97       |
# |    reward             | -0.22320725 |
# |    std                | 1.04        |
# |    value_loss         | 3.57        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1813       |
# |    iterations         | 8200       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | 4.84       |
# |    reward             | -1.6368561 |
# |    std                | 1.05       |
# |    value_loss         | 4.12       |
# --------------------------------------
# day: 702, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1384810.06
# total_reward: 384810.06
# total_cost: 26362.90
# total_trades: 1206
# Sharpe: 0.733
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1813         |
# |    iterations         | 8300         |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 41500        |
# | train/                |              |
# |    entropy_loss       | -2.91        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8299         |
# |    policy_loss        | -1.38        |
# |    reward             | -0.053905666 |
# |    std                | 1.04         |
# |    value_loss         | 0.533        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1814       |
# |    iterations         | 8400       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | -7.83      |
# |    reward             | -0.6880221 |
# |    std                | 1.04       |
# |    value_loss         | 8.01       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1815     |
# |    iterations         | 8500     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | -0.00553 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -2.73    |
# |    reward             | -1.39776 |
# |    std                | 1.04     |
# |    value_loss         | 1.41     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1814        |
# |    iterations         | 8600        |
# |    time_elapsed       | 23          |
# |    total_timesteps    | 43000       |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | 0.0779      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8599        |
# |    policy_loss        | -0.786      |
# |    reward             | 0.096392184 |
# |    std                | 1.04        |
# |    value_loss         | 1.15        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1815      |
# |    iterations         | 8700      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | 0.0237    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 0.184     |
# |    reward             | -1.494439 |
# |    std                | 1.04      |
# |    value_loss         | 1.02      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1815      |
# |    iterations         | 8800      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | 5.61      |
# |    reward             | 0.1644873 |
# |    std                | 1.05      |
# |    value_loss         | 3.03      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1816       |
# |    iterations         | 8900       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | -3.01      |
# |    reward             | 0.15090507 |
# |    std                | 1.05       |
# |    value_loss         | 1.65       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1817         |
# |    iterations         | 9000         |
# |    time_elapsed       | 24           |
# |    total_timesteps    | 45000        |
# | train/                |              |
# |    entropy_loss       | -2.93        |
# |    explained_variance | 0.0915       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8999         |
# |    policy_loss        | -7.02        |
# |    reward             | 0.0030396485 |
# |    std                | 1.05         |
# |    value_loss         | 15.1         |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1817         |
# |    iterations         | 9100         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 45500        |
# | train/                |              |
# |    entropy_loss       | -2.92        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9099         |
# |    policy_loss        | 3.16         |
# |    reward             | -0.061071925 |
# |    std                | 1.04         |
# |    value_loss         | 2.77         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1818        |
# |    iterations         | 9200        |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 46000       |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9199        |
# |    policy_loss        | -0.893      |
# |    reward             | -0.21556494 |
# |    std                | 1.04        |
# |    value_loss         | 0.36        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1819      |
# |    iterations         | 9300      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | 4.5       |
# |    reward             | 1.0892137 |
# |    std                | 1.04      |
# |    value_loss         | 3.66      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1820       |
# |    iterations         | 9400       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | -0.643     |
# |    reward             | -0.5643426 |
# |    std                | 1.04       |
# |    value_loss         | 0.317      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1820        |
# |    iterations         | 9500        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | -11.4       |
# |    reward             | -0.53146714 |
# |    std                | 1.04        |
# |    value_loss         | 24.4        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1821       |
# |    iterations         | 9600       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -0.172     |
# |    reward             | -0.5724832 |
# |    std                | 1.04       |
# |    value_loss         | 0.587      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1821        |
# |    iterations         | 9700        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 48500       |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9699        |
# |    policy_loss        | -2.91       |
# |    reward             | -0.09888477 |
# |    std                | 1.04        |
# |    value_loss         | 0.999       |
# ---------------------------------------
# day: 702, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 963
# Sharpe: 0.801
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1822      |
# |    iterations         | 9800      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -2.93     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -3.18     |
# |    reward             | 2.0329957 |
# |    std                | 1.05      |
# |    value_loss         | 1.73      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 1822       |
# |    iterations         | 9900       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | 3.74       |
# |    reward             | -0.6560446 |
# |    std                | 1.05       |
# |    value_loss         | 4.07       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1822     |
# |    iterations         | 10000    |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | -6.19    |
# |    reward             | 2.248173 |
# |    std                | 1.04     |
# |    value_loss         | 4.81     |
# ------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 251        |
# |    time_elapsed    | 11         |
# |    total_timesteps | 2812       |
# | train/             |            |
# |    actor_loss      | -261       |
# |    critic_loss     | 80.9       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 2711       |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 250        |
# |    time_elapsed    | 22         |
# |    total_timesteps | 5624       |
# | train/             |            |
# |    actor_loss      | -199       |
# |    critic_loss     | 1.35e+05   |
# |    learning_rate   | 0.001      |
# |    n_updates       | 5523       |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 253        |
# |    time_elapsed    | 33         |
# |    total_timesteps | 8436       |
# | train/             |            |
# |    actor_loss      | -270       |
# |    critic_loss     | 1.04e+03   |
# |    learning_rate   | 0.001      |
# |    n_updates       | 8335       |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 258        |
# |    time_elapsed    | 43         |
# |    total_timesteps | 11248      |
# | train/             |            |
# |    actor_loss      | -259       |
# |    critic_loss     | 222        |
# |    learning_rate   | 0.001      |
# |    n_updates       | 11147      |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 261        |
# |    time_elapsed    | 53         |
# |    total_timesteps | 14060      |
# | train/             |            |
# |    actor_loss      | -224       |
# |    critic_loss     | 18.9       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 13959      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 24         |
# |    fps             | 263        |
# |    time_elapsed    | 63         |
# |    total_timesteps | 16872      |
# | train/             |            |
# |    actor_loss      | -197       |
# |    critic_loss     | 16.4       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 16771      |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 28         |
# |    fps             | 265        |
# |    time_elapsed    | 74         |
# |    total_timesteps | 19684      |
# | train/             |            |
# |    actor_loss      | -164       |
# |    critic_loss     | 10.1       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 19583      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 32         |
# |    fps             | 266        |
# |    time_elapsed    | 84         |
# |    total_timesteps | 22496      |
# | train/             |            |
# |    actor_loss      | -143       |
# |    critic_loss     | 9.78       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 22395      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 36         |
# |    fps             | 261        |
# |    time_elapsed    | 96         |
# |    total_timesteps | 25308      |
# | train/             |            |
# |    actor_loss      | -120       |
# |    critic_loss     | 16.5       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 25207      |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 40         |
# |    fps             | 259        |
# |    time_elapsed    | 108        |
# |    total_timesteps | 28120      |
# | train/             |            |
# |    actor_loss      | -101       |
# |    critic_loss     | 9.43       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 28019      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 44         |
# |    fps             | 257        |
# |    time_elapsed    | 120        |
# |    total_timesteps | 30932      |
# | train/             |            |
# |    actor_loss      | -86        |
# |    critic_loss     | 5.3        |
# |    learning_rate   | 0.001      |
# |    n_updates       | 30831      |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 48         |
# |    fps             | 258        |
# |    time_elapsed    | 130        |
# |    total_timesteps | 33744      |
# | train/             |            |
# |    actor_loss      | -74.9      |
# |    critic_loss     | 7.06       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 33643      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 52         |
# |    fps             | 261        |
# |    time_elapsed    | 140        |
# |    total_timesteps | 36556      |
# | train/             |            |
# |    actor_loss      | -61.6      |
# |    critic_loss     | 48.6       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 36455      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 56         |
# |    fps             | 259        |
# |    time_elapsed    | 151        |
# |    total_timesteps | 39368      |
# | train/             |            |
# |    actor_loss      | -54.1      |
# |    critic_loss     | 3.87       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 39267      |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 60         |
# |    fps             | 261        |
# |    time_elapsed    | 161        |
# |    total_timesteps | 42180      |
# | train/             |            |
# |    actor_loss      | -46.6      |
# |    critic_loss     | 2.19       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 42079      |
# |    reward          | 0.81124943 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 64         |
# |    fps             | 263        |
# |    time_elapsed    | 170        |
# |    total_timesteps | 44992      |
# | train/             |            |
# |    actor_loss      | -39.8      |
# |    critic_loss     | 4.43       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 44891      |
# |    reward          | 0.81124943 |
# -----------------------------------
# day: 702, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1436466.40
# total_reward: 436466.40
# total_cost: 996.61
# total_trades: 702
# Sharpe: 0.801
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 68         |
# |    fps             | 265        |
# |    time_elapsed    | 180        |
# |    total_timesteps | 47804      |
# | train/             |            |
# |    actor_loss      | -34.9      |
# |    critic_loss     | 1.56       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 47703      |
# |    reward          | 0.81124943 |
# -----------------------------------

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 2863      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | -1.971305 |
# ----------------------------------
# day: 702, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 1025570.68
# total_reward: 25570.68
# total_cost: 278895.40
# total_trades: 1233
# Sharpe: 0.138
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2588         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036072654 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0519      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.8          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00374     |
# |    reward               | 0.80994964   |
# |    std                  | 1            |
# |    value_loss           | 10.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2515        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003995687 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -0.00602    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.05        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00268    |
# |    reward               | 1.834761    |
# |    std                  | 0.996       |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2471         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0031774435 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.00177     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.88         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00145     |
# |    reward               | 0.48607117   |
# |    std                  | 0.995        |
# |    value_loss           | 10.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2408        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004368034 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -0.00447    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.71        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00211    |
# |    reward               | -1.010532   |
# |    std                  | 0.994       |
# |    value_loss           | 9.88        |
# -----------------------------------------
# day: 702, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 1337434.47
# total_reward: 337434.47
# total_cost: 243132.86
# total_trades: 1223
# Sharpe: 0.702
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2395         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0048861955 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.00216     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.69         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00351     |
# |    reward               | 0.008516884  |
# |    std                  | 0.989        |
# |    value_loss           | 13.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2397         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0033426944 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00186      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.93         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00419     |
# |    reward               | -3.3952742   |
# |    std                  | 0.986        |
# |    value_loss           | 12.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2396         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0048938645 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00513      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.3          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00307     |
# |    reward               | 0.34986195   |
# |    std                  | 0.983        |
# |    value_loss           | 11.3         |
# ------------------------------------------
# day: 702, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 1192187.87
# total_reward: 192187.87
# total_cost: 244511.22
# total_trades: 1269
# Sharpe: 0.432
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2397         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0074796434 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | -0.0044      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.29         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00458     |
# |    reward               | 1.0690554    |
# |    std                  | 0.981        |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2394         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0023567807 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.00319      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.76         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00327     |
# |    reward               | -0.021193184 |
# |    std                  | 0.983        |
# |    value_loss           | 16.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2396         |
# |    iterations           | 11           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0047370354 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00212      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.62         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00339     |
# |    reward               | -0.2709601   |
# |    std                  | 0.987        |
# |    value_loss           | 15.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2396        |
# |    iterations           | 12          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005660162 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.00869     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.03        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0039     |
# |    reward               | 1.2854761   |
# |    std                  | 0.988       |
# |    value_loss           | 15.6        |
# -----------------------------------------
# day: 702, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 1185229.29
# total_reward: 185229.29
# total_cost: 252836.58
# total_trades: 1281
# Sharpe: 0.410
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2391        |
# |    iterations           | 13          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005387233 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.00193     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00343    |
# |    reward               | -1.1792485  |
# |    std                  | 0.984       |
# |    value_loss           | 20.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2391         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0026998995 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00267      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.92         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00159     |
# |    reward               | -0.19423646  |
# |    std                  | 0.983        |
# |    value_loss           | 23.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2390         |
# |    iterations           | 15           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0035855966 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.00212      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 10.1         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0022      |
# |    reward               | 2.4396696    |
# |    std                  | 0.983        |
# |    value_loss           | 20.8         |
# ------------------------------------------
# day: 702, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1370537.96
# total_reward: 370537.96
# total_cost: 198736.78
# total_trades: 1278
# Sharpe: 0.651
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2388         |
# |    iterations           | 16           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033509808 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00798      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.3         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00245     |
# |    reward               | 1.2402151    |
# |    std                  | 0.989        |
# |    value_loss           | 20.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2387         |
# |    iterations           | 17           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0030449573 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.00544      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11           |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00175     |
# |    reward               | -0.10961674  |
# |    std                  | 0.988        |
# |    value_loss           | 24.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2386         |
# |    iterations           | 18           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0040954053 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00178      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00345     |
# |    reward               | 2.034137     |
# |    std                  | 0.986        |
# |    value_loss           | 23.3         |
# ------------------------------------------
# day: 702, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1604599.30
# total_reward: 604599.30
# total_cost: 243947.93
# total_trades: 1269
# Sharpe: 0.917
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2386         |
# |    iterations           | 19           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0029536753 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0175       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.94         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000261    |
# |    reward               | -9.941993    |
# |    std                  | 0.985        |
# |    value_loss           | 19.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2382         |
# |    iterations           | 20           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0065105334 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00296      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.7         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00316     |
# |    reward               | 1.0467201    |
# |    std                  | 0.986        |
# |    value_loss           | 21.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2383        |
# |    iterations           | 21          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005038664 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0133      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00357    |
# |    reward               | 0.55652744  |
# |    std                  | 0.987       |
# |    value_loss           | 21.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2380         |
# |    iterations           | 22           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0035078502 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0196       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000688    |
# |    reward               | -0.03217203  |
# |    std                  | 0.985        |
# |    value_loss           | 24.5         |
# ------------------------------------------
# day: 702, episode: 210
# begin_total_asset: 1000000.00
# end_total_asset: 2001996.35
# total_reward: 1001996.35
# total_cost: 191873.41
# total_trades: 1289
# Sharpe: 1.287
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2373       |
# |    iterations           | 23         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00591821 |
# |    clip_fraction        | 0.0549     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.8       |
# |    explained_variance   | 0.0349     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.5        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00348   |
# |    reward               | 0.71615547 |
# |    std                  | 0.981      |
# |    value_loss           | 19.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2371        |
# |    iterations           | 24          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007950333 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.0214      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.5        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00219    |
# |    reward               | -0.5179317  |
# |    std                  | 0.986       |
# |    value_loss           | 29.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2370         |
# |    iterations           | 25           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0030690667 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00602      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000681    |
# |    reward               | -0.037400585 |
# |    std                  | 0.986        |
# |    value_loss           | 28.5         |
# ------------------------------------------
# day: 702, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 1556841.04
# total_reward: 556841.04
# total_cost: 153137.81
# total_trades: 1305
# Sharpe: 0.839
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2369         |
# |    iterations           | 26           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024725026 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0356       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.2         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000917    |
# |    reward               | -1.0062262   |
# |    std                  | 0.987        |
# |    value_loss           | 26.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2369        |
# |    iterations           | 27          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006325058 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.022       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00112    |
# |    reward               | -1.173839   |
# |    std                  | 0.988       |
# |    value_loss           | 27.9        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2368          |
# |    iterations           | 28            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00034459212 |
# |    clip_fraction        | 0.00796       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.0513        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 12.8          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | 0.000169      |
# |    reward               | -1.1576385    |
# |    std                  | 0.987         |
# |    value_loss           | 29.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2361         |
# |    iterations           | 29           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0042759343 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0594       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00168     |
# |    reward               | 0.45633027   |
# |    std                  | 0.986        |
# |    value_loss           | 28.7         |
# ------------------------------------------
# day: 702, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1765195.92
# total_reward: 765195.92
# total_cost: 135470.11
# total_trades: 1261
# Sharpe: 1.022
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2360        |
# |    iterations           | 30          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.003988366 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0543      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00179    |
# |    reward               | -0.36721534 |
# |    std                  | 0.984       |
# |    value_loss           | 29.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2358         |
# |    iterations           | 31           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0014441146 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.0325       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 20           |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00238     |
# |    reward               | -0.81505775  |
# |    std                  | 0.985        |
# |    value_loss           | 32.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2358         |
# |    iterations           | 32           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0030796672 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0693       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.000716     |
# |    reward               | 0.53492695   |
# |    std                  | 0.985        |
# |    value_loss           | 32.7         |
# ------------------------------------------
# day: 702, episode: 240
# begin_total_asset: 1000000.00
# end_total_asset: 2105233.08
# total_reward: 1105233.08
# total_cost: 102320.40
# total_trades: 1272
# Sharpe: 1.290
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2357        |
# |    iterations           | 33          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003350267 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0361      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000366    |
# |    reward               | 4.641641    |
# |    std                  | 0.987       |
# |    value_loss           | 34.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2358         |
# |    iterations           | 34           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0025341052 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0477       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.5         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0012      |
# |    reward               | 2.8313894    |
# |    std                  | 0.986        |
# |    value_loss           | 34.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2357         |
# |    iterations           | 35           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0020957068 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0267       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 23.1         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000289    |
# |    reward               | -0.22541778  |
# |    std                  | 0.988        |
# |    value_loss           | 33.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2354         |
# |    iterations           | 36           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0009372101 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0511       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.8         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -9.03e-05    |
# |    reward               | 0.41860148   |
# |    std                  | 0.985        |
# |    value_loss           | 35.6         |
# ------------------------------------------
# day: 702, episode: 250
# begin_total_asset: 1000000.00
# end_total_asset: 1867734.40
# total_reward: 867734.40
# total_cost: 81083.08
# total_trades: 1284
# Sharpe: 1.077
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2346       |
# |    iterations           | 37         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00805375 |
# |    clip_fraction        | 0.0422     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.8       |
# |    explained_variance   | 0.0245     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 16.3       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.000919  |
# |    reward               | -1.5410794 |
# |    std                  | 0.983      |
# |    value_loss           | 33.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2345         |
# |    iterations           | 38           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0019874529 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.051        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18.2         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00021     |
# |    reward               | -2.707853    |
# |    std                  | 0.984        |
# |    value_loss           | 38.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2345         |
# |    iterations           | 39           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0031623517 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0381       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18.4         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000424     |
# |    reward               | 0.6955063    |
# |    std                  | 0.984        |
# |    value_loss           | 36           |
# ------------------------------------------
# day: 702, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 1729269.14
# total_reward: 729269.14
# total_cost: 71845.55
# total_trades: 1272
# Sharpe: 0.965
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2346         |
# |    iterations           | 40           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0032768487 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0478       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.2         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000992    |
# |    reward               | 0.11540537   |
# |    std                  | 0.988        |
# |    value_loss           | 34.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2345         |
# |    iterations           | 41           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0020397913 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0359       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.8         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000558    |
# |    reward               | -0.42695147  |
# |    std                  | 0.983        |
# |    value_loss           | 37           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2344         |
# |    iterations           | 42           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0036699874 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0286       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.4         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000562    |
# |    reward               | 3.8803442    |
# |    std                  | 0.986        |
# |    value_loss           | 37.4         |
# ------------------------------------------
# day: 702, episode: 270
# begin_total_asset: 1000000.00
# end_total_asset: 1947872.89
# total_reward: 947872.89
# total_cost: 47493.96
# total_trades: 1266
# Sharpe: 1.131
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2339         |
# |    iterations           | 43           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0014257985 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.013        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 23.9         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00044      |
# |    reward               | -0.88996524  |
# |    std                  | 0.986        |
# |    value_loss           | 37.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2340         |
# |    iterations           | 44           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0019345353 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0293       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.6         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00121     |
# |    reward               | 0.05684375   |
# |    std                  | 0.987        |
# |    value_loss           | 39.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2340        |
# |    iterations           | 45          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005074544 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0286      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000466   |
# |    reward               | -1.0322751  |
# |    std                  | 0.986       |
# |    value_loss           | 39.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2340         |
# |    iterations           | 46           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0018090437 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00725      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.5         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000288     |
# |    reward               | -0.8816655   |
# |    std                  | 0.986        |
# |    value_loss           | 39.4         |
# ------------------------------------------
# day: 702, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 2096077.39
# total_reward: 1096077.39
# total_cost: 65267.21
# total_trades: 1270
# Sharpe: 1.267
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2340         |
# |    iterations           | 47           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0022308037 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0218       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.2         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00178     |
# |    reward               | -0.15795264  |
# |    std                  | 0.99         |
# |    value_loss           | 38           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2331         |
# |    iterations           | 48           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0050935633 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.00295      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.6         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00106     |
# |    reward               | -0.52835107  |
# |    std                  | 0.994        |
# |    value_loss           | 39.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2324         |
# |    iterations           | 49           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0011269291 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.00211     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 23.1         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00203     |
# |    reward               | -1.3426871   |
# |    std                  | 0.994        |
# |    value_loss           | 38.2         |
# ------------------------------------------
# day: 702, episode: 290
# begin_total_asset: 1000000.00
# end_total_asset: 1695312.88
# total_reward: 695312.88
# total_cost: 80910.86
# total_trades: 1298
# Sharpe: 0.932
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2323        |
# |    iterations           | 50          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.003219385 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.1        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0009     |
# |    reward               | 2.9151404   |
# |    std                  | 0.992       |
# |    value_loss           | 37.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2319         |
# |    iterations           | 51           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0021026628 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0706       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.5         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00164     |
# |    reward               | -4.1341515   |
# |    std                  | 0.995        |
# |    value_loss           | 31.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2318         |
# |    iterations           | 52           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0030938732 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0712       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18.4         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00179     |
# |    reward               | -0.77685803  |
# |    std                  | 0.99         |
# |    value_loss           | 34.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2317       |
# |    iterations           | 53         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.00483205 |
# |    clip_fraction        | 0.0228     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.0498     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 18.7       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00117   |
# |    reward               | 3.106751   |
# |    std                  | 0.99       |
# |    value_loss           | 33.5       |
# ----------------------------------------
# day: 702, episode: 300
# begin_total_asset: 1000000.00
# end_total_asset: 2016831.75
# total_reward: 1016831.75
# total_cost: 49716.53
# total_trades: 1262
# Sharpe: 1.184
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2313         |
# |    iterations           | 54           |
# ...
# |    approx_kl            | 0.004078216 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.5        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.000261   |
# |    reward               | 1.7463522   |
# |    std                  | 0.995       |
# |    value_loss           | 29.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2324         |
# |    iterations           | 82           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0036738808 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.2         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00183     |
# |    reward               | 0.2894458    |
# |    std                  | 0.988        |
# |    value_loss           | 28.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2325        |
# |    iterations           | 83          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.004523216 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.5        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00285    |
# |    reward               | 2.461754    |
# |    std                  | 0.989       |
# |    value_loss           | 30.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2326        |
# |    iterations           | 84          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005528614 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.2        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.000435    |
# |    reward               | -4.210397   |
# |    std                  | 0.989       |
# |    value_loss           | 32.2        |
# -----------------------------------------
# day: 702, episode: 390
# begin_total_asset: 1000000.00
# end_total_asset: 1957999.35
# total_reward: 957999.35
# total_cost: 26260.70
# total_trades: 1367
# Sharpe: 1.134
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2326          |
# |    iterations           | 85            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00041260858 |
# |    clip_fraction        | 0.0171        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.326         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 15            |
# |    n_updates            | 840           |
# |    policy_gradient_loss | 0.000509      |
# |    reward               | 1.0079781     |
# |    std                  | 0.989         |
# |    value_loss           | 30.2          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2324        |
# |    iterations           | 86          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.010256323 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.315       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.3        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00148    |
# |    reward               | 0.35195246  |
# |    std                  | 0.991       |
# |    value_loss           | 29.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2325         |
# |    iterations           | 87           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0060495418 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.4         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -6.02e-05    |
# |    reward               | 1.7951659    |
# |    std                  | 0.994        |
# |    value_loss           | 33.2         |
# ------------------------------------------
# day: 702, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 1991935.23
# total_reward: 991935.23
# total_cost: 6989.08
# total_trades: 1300
# Sharpe: 1.162
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2325         |
# |    iterations           | 88           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0031175201 |
# |    clip_fraction        | 0.0743       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12           |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.000289     |
# |    reward               | 0.71443963   |
# |    std                  | 0.991        |
# |    value_loss           | 28.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2325        |
# |    iterations           | 89          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.004800493 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.1        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00136    |
# |    reward               | 0.7406164   |
# |    std                  | 0.99        |
# |    value_loss           | 29.9        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2326          |
# |    iterations           | 90            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00019258983 |
# |    clip_fraction        | 0.0372        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 0.292         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 15.7          |
# |    n_updates            | 890           |
# |    policy_gradient_loss | 0.000297      |
# |    reward               | -2.0640945    |
# |    std                  | 0.991         |
# |    value_loss           | 31.1          |
# -------------------------------------------
# day: 702, episode: 410
# begin_total_asset: 1000000.00
# end_total_asset: 2015423.03
# total_reward: 1015423.03
# total_cost: 7033.36
# total_trades: 1349
# Sharpe: 1.173
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2326        |
# |    iterations           | 91          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.011691903 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22          |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00222    |
# |    reward               | 1.9887753   |
# |    std                  | 0.989       |
# |    value_loss           | 34          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2327        |
# |    iterations           | 92          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.005419916 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.2        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.000819   |
# |    reward               | 0.07989536  |
# |    std                  | 0.989       |
# |    value_loss           | 32.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2328         |
# |    iterations           | 93           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0025056861 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.273        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.2         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00104     |
# |    reward               | 0.64144546   |
# |    std                  | 0.992        |
# |    value_loss           | 31.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2329        |
# |    iterations           | 94          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.007216342 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.6        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00135    |
# |    reward               | 0.26785982  |
# |    std                  | 0.995       |
# |    value_loss           | 29.8        |
# -----------------------------------------
# day: 702, episode: 420
# begin_total_asset: 1000000.00
# end_total_asset: 2018493.11
# total_reward: 1018493.11
# total_cost: 29547.56
# total_trades: 1320
# Sharpe: 1.188
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2330         |
# |    iterations           | 95           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0062627206 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.4         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.000335     |
# |    reward               | -0.742496    |
# |    std                  | 1            |
# |    value_loss           | 29.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2330         |
# |    iterations           | 96           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0022586887 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.7         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00157     |
# |    reward               | -0.4984977   |
# |    std                  | 1.01         |
# |    value_loss           | 30.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2331        |
# |    iterations           | 97          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.007890169 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.1        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00356    |
# |    reward               | 5.536938    |
# |    std                  | 1           |
# |    value_loss           | 30.4        |
# -----------------------------------------
# day: 702, episode: 430
# begin_total_asset: 1000000.00
# end_total_asset: 2035539.07
# total_reward: 1035539.07
# total_cost: 12870.21
# total_trades: 1323
# Sharpe: 1.189
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2331        |
# |    iterations           | 98          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.010576966 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.9        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00185    |
# |    reward               | 3.210495    |
# |    std                  | 1           |
# |    value_loss           | 32.8        |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 274       |
# |    time_elapsed    | 10        |
# |    total_timesteps | 2812      |
# | train/             |           |
# |    actor_loss      | 2.5e+03   |
# |    critic_loss     | 1.44e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2711      |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 281       |
# |    time_elapsed    | 20        |
# |    total_timesteps | 5624      |
# | train/             |           |
# |    actor_loss      | 2.46e+03  |
# |    critic_loss     | 7.09e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5523      |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 440
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 288       |
# |    time_elapsed    | 29        |
# |    total_timesteps | 8436      |
# | train/             |           |
# |    actor_loss      | 2.38e+03  |
# |    critic_loss     | 1.54e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8335      |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 289       |
# |    time_elapsed    | 38        |
# |    total_timesteps | 11248     |
# | train/             |           |
# |    actor_loss      | 2.27e+03  |
# |    critic_loss     | 1.15e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11147     |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 450
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 293       |
# |    time_elapsed    | 47        |
# |    total_timesteps | 14060     |
# | train/             |           |
# |    actor_loss      | 2.09e+03  |
# |    critic_loss     | 5.19e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13959     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 294       |
# |    time_elapsed    | 57        |
# |    total_timesteps | 16872     |
# | train/             |           |
# |    actor_loss      | 1.93e+03  |
# |    critic_loss     | 1.34e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16771     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 294       |
# |    time_elapsed    | 66        |
# |    total_timesteps | 19684     |
# | train/             |           |
# |    actor_loss      | 1.78e+03  |
# |    critic_loss     | 2.82e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19583     |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 460
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 294       |
# |    time_elapsed    | 76        |
# |    total_timesteps | 22496     |
# | train/             |           |
# |    actor_loss      | 1.64e+03  |
# |    critic_loss     | 1.75e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22395     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 291       |
# |    time_elapsed    | 86        |
# |    total_timesteps | 25308     |
# | train/             |           |
# |    actor_loss      | 1.52e+03  |
# |    critic_loss     | 841       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25207     |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 470
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 287       |
# |    time_elapsed    | 97        |
# |    total_timesteps | 28120     |
# | train/             |           |
# |    actor_loss      | 1.4e+03   |
# |    critic_loss     | 1.68e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28019     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 285       |
# |    time_elapsed    | 108       |
# |    total_timesteps | 30932     |
# | train/             |           |
# |    actor_loss      | 1.33e+03  |
# |    critic_loss     | 4.29e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30831     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 286       |
# |    time_elapsed    | 117       |
# |    total_timesteps | 33744     |
# | train/             |           |
# |    actor_loss      | 1.21e+03  |
# |    critic_loss     | 1.85e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33643     |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 480
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 285       |
# |    time_elapsed    | 128       |
# |    total_timesteps | 36556     |
# | train/             |           |
# |    actor_loss      | 1.15e+03  |
# |    critic_loss     | 1.03e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36455     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 282       |
# |    time_elapsed    | 139       |
# |    total_timesteps | 39368     |
# | train/             |           |
# |    actor_loss      | 1.04e+03  |
# |    critic_loss     | 1.18e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39267     |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 490
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 282       |
# |    time_elapsed    | 149       |
# |    total_timesteps | 42180     |
# | train/             |           |
# |    actor_loss      | 1.02e+03  |
# |    critic_loss     | 1.98e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42079     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 281       |
# |    time_elapsed    | 159       |
# |    total_timesteps | 44992     |
# | train/             |           |
# |    actor_loss      | 941       |
# |    critic_loss     | 488       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44891     |
# |    reward          | 0.8313751 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 279       |
# |    time_elapsed    | 170       |
# |    total_timesteps | 47804     |
# | train/             |           |
# |    actor_loss      | 901       |
# |    critic_loss     | 388       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47703     |
# |    reward          | 0.8313751 |
# ----------------------------------
# day: 702, episode: 500
# begin_total_asset: 1000000.00
# end_total_asset: 1884765.87
# total_reward: 884765.87
# total_cost: 997.30
# total_trades: 1404
# Sharpe: 1.123
# =================================

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None
# Out:
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 206      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2812     |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 1.41e+04 |
# |    ent_coef        | 0.131    |
# |    ent_coef_loss   | 38.2     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2711     |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 510
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 214      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 5624     |
# | train/             |          |
# |    actor_loss      | 245      |
# |    critic_loss     | 1.44e+04 |
# |    ent_coef        | 0.174    |
# |    ent_coef_loss   | 32.9     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5523     |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 221      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 8436     |
# | train/             |          |
# |    actor_loss      | 382      |
# |    critic_loss     | 6.96e+04 |
# |    ent_coef        | 0.23     |
# |    ent_coef_loss   | 27.7     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8335     |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 222      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 11248    |
# | train/             |          |
# |    actor_loss      | 371      |
# |    critic_loss     | 5.87e+03 |
# |    ent_coef        | 0.305    |
# |    ent_coef_loss   | 22.2     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11147    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 520
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 224      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 14060    |
# | train/             |          |
# |    actor_loss      | 511      |
# |    critic_loss     | 1.74e+04 |
# |    ent_coef        | 0.404    |
# |    ent_coef_loss   | 17.1     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13959    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 225      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 16872    |
# | train/             |          |
# |    actor_loss      | 844      |
# |    critic_loss     | 5.39e+04 |
# |    ent_coef        | 0.535    |
# |    ent_coef_loss   | 11.8     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16771    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 530
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 224      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 19684    |
# | train/             |          |
# |    actor_loss      | 683      |
# |    critic_loss     | 363      |
# |    ent_coef        | 0.708    |
# |    ent_coef_loss   | 6.48     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19583    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 224      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 22496    |
# | train/             |          |
# |    actor_loss      | 988      |
# |    critic_loss     | 6.31e+03 |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22395    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 225      |
# |    time_elapsed    | 112      |
# |    total_timesteps | 25308    |
# | train/             |          |
# |    actor_loss      | 1.16e+03 |
# |    critic_loss     | 2.06e+03 |
# |    ent_coef        | 1.24     |
# |    ent_coef_loss   | -4.07    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25207    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 540
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 225      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 28120    |
# | train/             |          |
# |    actor_loss      | 1.3e+03  |
# |    critic_loss     | 7.37e+03 |
# |    ent_coef        | 1.65     |
# |    ent_coef_loss   | -9.41    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28019    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 227      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 30932    |
# | train/             |          |
# |    actor_loss      | 1.75e+03 |
# |    critic_loss     | 4.97e+03 |
# |    ent_coef        | 2.18     |
# |    ent_coef_loss   | -14.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30831    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 550
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 227      |
# |    time_elapsed    | 148      |
# |    total_timesteps | 33744    |
# | train/             |          |
# |    actor_loss      | 2.35e+03 |
# |    critic_loss     | 9.52e+03 |
# |    ent_coef        | 2.89     |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33643    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 228      |
# |    time_elapsed    | 159      |
# |    total_timesteps | 36556    |
# | train/             |          |
# |    actor_loss      | 2.98e+03 |
# |    critic_loss     | 7.01e+03 |
# |    ent_coef        | 3.83     |
# |    ent_coef_loss   | -25.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36455    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 228      |
# |    time_elapsed    | 172      |
# |    total_timesteps | 39368    |
# | train/             |          |
# |    actor_loss      | 3.89e+03 |
# |    critic_loss     | 1.12e+05 |
# |    ent_coef        | 5.07     |
# |    ent_coef_loss   | -30.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 39267    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 560
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 228      |
# |    time_elapsed    | 184      |
# |    total_timesteps | 42180    |
# | train/             |          |
# |    actor_loss      | 5.12e+03 |
# |    critic_loss     | 5.71e+03 |
# |    ent_coef        | 6.72     |
# |    ent_coef_loss   | -35.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 42079    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 228      |
# |    time_elapsed    | 197      |
# |    total_timesteps | 44992    |
# | train/             |          |
# |    actor_loss      | 6.66e+03 |
# |    critic_loss     | 1.39e+04 |
# |    ent_coef        | 8.9      |
# |    ent_coef_loss   | -40.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 44891    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 570
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 227      |
# |    time_elapsed    | 209      |
# |    total_timesteps | 47804    |
# | train/             |          |
# |    actor_loss      | 8.63e+03 |
# |    critic_loss     | 4.09e+03 |
# |    ent_coef        | 11.8     |
# |    ent_coef_loss   | -46.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 47703    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 224      |
# |    time_elapsed    | 225      |
# |    total_timesteps | 50616    |
# | train/             |          |
# |    actor_loss      | 1.12e+04 |
# |    critic_loss     | 4.33e+03 |
# |    ent_coef        | 15.6     |
# |    ent_coef_loss   | -51.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 50515    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 223      |
# |    time_elapsed    | 238      |
# |    total_timesteps | 53428    |
# | train/             |          |
# |    actor_loss      | 1.42e+04 |
# |    critic_loss     | 7.03e+04 |
# |    ent_coef        | 20.7     |
# |    ent_coef_loss   | -57.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53327    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 580
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 223      |
# |    time_elapsed    | 251      |
# |    total_timesteps | 56240    |
# | train/             |          |
# |    actor_loss      | 1.89e+04 |
# |    critic_loss     | 4.41e+04 |
# |    ent_coef        | 27.4     |
# |    ent_coef_loss   | -62.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56139    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 223      |
# |    time_elapsed    | 264      |
# |    total_timesteps | 59052    |
# | train/             |          |
# |    actor_loss      | 2.52e+04 |
# |    critic_loss     | 1.06e+05 |
# |    ent_coef        | 36.3     |
# |    ent_coef_loss   | -67.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 58951    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 590
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 223      |
# |    time_elapsed    | 277      |
# |    total_timesteps | 61864    |
# | train/             |          |
# |    actor_loss      | 3.35e+04 |
# |    critic_loss     | 4.83e+05 |
# |    ent_coef        | 48.1     |
# |    ent_coef_loss   | -72      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61763    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 222      |
# |    time_elapsed    | 291      |
# |    total_timesteps | 64676    |
# | train/             |          |
# |    actor_loss      | 4.44e+04 |
# |    critic_loss     | 1.67e+04 |
# |    ent_coef        | 63.7     |
# |    ent_coef_loss   | -78      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 64575    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 221      |
# |    time_elapsed    | 304      |
# |    total_timesteps | 67488    |
# | train/             |          |
# |    actor_loss      | 5.89e+04 |
# |    critic_loss     | 1.89e+05 |
# |    ent_coef        | 84.4     |
# |    ent_coef_loss   | -83      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 67387    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 702, episode: 600
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## Save the trained agent
# Trained agents should have already been saved in the "trained_models" drectory after you run the code blocks above.
#
# For Colab users, the zip files should be at "./trained_models" or "/content/trained_models".
#
# For users running on your local environment, the zip files should be at "./trained_models".
