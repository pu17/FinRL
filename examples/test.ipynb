# %%
import tushare as ts

# 确保你已经设置了 Tushare token
ts.set_token('4bccdd4d130c436773beef521fbecc05ab0079026122c370908f3c93')

# 初始化 API 接口
pro = ts.pro_api()

# 测试获取 600000.SH 的历史数据
data = ts.pro_bar(ts_code='600000.SH', start_date='20220101', end_date='20221231', freq='D')

# 输出数据
print(data)
# Out:
#        ts_code trade_date  open  high   low  close  pre_close  change  \
# 0    600000.SH   20221230  7.23  7.30  7.22   7.28       7.24    0.04
# 1    600000.SH   20221229  7.27  7.29  7.18   7.24       7.30   -0.06
# 2    600000.SH   20221228  7.22  7.30  7.20   7.30       7.22    0.08
# 3    600000.SH   20221227  7.13  7.29  7.12   7.22       7.10    0.12
# 4    600000.SH   20221226  7.19  7.21  7.08   7.10       7.19   -0.09
# ..         ...        ...   ...   ...   ...    ...        ...     ...
# 237  600000.SH   20220110  8.72  8.78  8.66   8.72       8.71    0.01
# 238  600000.SH   20220107  8.57  8.73  8.57   8.71       8.57    0.14
# 239  600000.SH   20220106  8.66  8.66  8.56   8.57       8.64   -0.07
# 240  600000.SH   20220105  8.57  8.68  8.56   8.64       8.57    0.07
# 241  600000.SH   20220104  8.54  8.58  8.52   8.57        NaN     NaN
#
#      pct_chg        vol      amount
# 0       0.55  203523.97  147932.731
# 1      -0.82  183670.88  132652.083
# ...

# %%
import yfinance as yf

ticker_list = ["SMCI"]
start_date = "2019-01-01"
end_date = "2021-08-01"

for ticker in ticker_list:
    try:
        data = yf.download(ticker, start=start_date, end=end_date)
        print(f"Downloaded data for {ticker}:")
        print(data.head())
    except Exception as e:
        print(f"Failed to download data for {ticker}: {e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Downloaded data for SMCI:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2019-01-02  13.79  15.22  13.79  15.10      15.10  232600
# 2019-01-03  15.09  15.79  14.50  15.70      15.70  321700
# 2019-01-04  15.55  15.85  15.25  15.56      15.56  159500
# 2019-01-07  15.40  15.80  15.25  15.70      15.70  307800
# 2019-01-08  15.80  15.85  15.52  15.60      15.60  165100

# %%
import yfinance as yf

# 尝试获取较短时间范围的数据
smci_data = yf.download("SMCI", start="2019-06-23", end="2019-06-2")
print(smci_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-06-03  18.990000  19.490000  18.990000  19.299999  19.299999  143700
# 2019-06-04  19.299999  19.730000  18.969999  19.000000  19.000000  118700
# 2019-06-05  19.440001  19.500000  18.850000  18.850000  18.850000   39900
# 2019-06-06  18.850000  18.850000  18.010000  18.299999  18.299999  110600
# 2019-06-07  18.299999  18.450001  18.230000  18.350000  18.350000   46700
# 2019-06-10  18.980000  18.990000  18.450001  18.459999  18.459999   41700
# 2019-06-11  18.500000  18.900000  18.270000  18.370001  18.370001   72900
# 2019-06-12  18.450001  18.450001  18.139999  18.180000  18.180000   49900
# 2019-06-13  18.139999  18.180000  17.129999  17.389999  17.389999  204400
# 2019-06-14  17.299999  17.549999  17.260000  17.540001  17.540001  217300
# 2019-06-17  17.450001  18.200001  17.400000  18.000000  18.000000  101400
# ...
